# %%
import pyabc
from study_abc_noise.model import MRNATranscriptionModelVars as ModelVars
import matplotlib.pyplot as plt
import numpy as np
import os
import logging
import pickle
# %matplotlib inline

# for debugging
for module in ['Distance', 'Acceptor', 'Epsilon']:
    logger = logging.getLogger(module)
    logger.setLevel(logging.DEBUG)
    fh = logging.FileHandler('log/logger_laplace.log')
    fh.setLevel(logging.DEBUG)
    logger.addHandler(fh)

arr_n_t = [3, 5, 10, 15, 30, 100]
arr_n_t = [10]

succ_prob=0.95

# create data
for n_t in reversed(arr_n_t):
    fn = f"data/data_{n_t}_{succ_prob}.p"
    mv = ModelVars(n_t=n_t, noise_success_probability=succ_prob)
    if not os.path.isfile(fn):
        print(f"generate data for time {n_t}")
        data_exact = mv.get_model()(mv.p_true)
        data = mv.add_noise_to_data(data_exact)
        pickle.dump((data_exact, data), open(fn, "wb"))
    data_exact, data = pickle.load(open(fn, "rb"))
    plt.plot(data['t'], data['mrna'], 'x-')
    plt.plot(data['t'], data_exact['mrna'], 'x-', color='grey')
# Out:
# generate data for time 10

# %%
# proposed method

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t, noise_success_probability=succ_prob)
    fb = f"mrna_{n_t}_{succ_prob}_stochacc_v2"
    if os.path.isfile(f"{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log/log_temperature_{fb}.json", schemes=[
            pyabc.AcceptanceRateScheme(), pyabc.ExpDecayFixedRatioScheme(alpha=0.75)]),
       acceptor=pyabc.StochasticAcceptor(log_file=f"log/log_acceptor_{fb}.json"),
        population_size=1000,
        sampler=pyabc.sampler.MulticoreEvalParallelSampler(n_procs=20, check_max_eval=True)
    )
    data = pickle.load(open(f"data/data_{n_t}_{succ_prob}.p", "rb"))[1]
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run()#min_acceptance_rate=1e-4)
    print()
# Out:
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-30 11:45:23.153074, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=-8.5612e+01 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [3167.2708134711866].
# INFO:ABC:t: 0, eps: 3167.2708134711866.
# DEBUG:Acceptor:Encountered pd=-6.6582e+01 > c=-8.5612e+01, thus weight=1.0060e+00.
# DEBUG:Acceptor:Encountered pd=-7.8423e+01 > c=-8.5612e+01, thus weight=1.0023e+00.
# DEBUG:Acceptor:Encountered pd=-5.9847e+01 > c=-8.5612e+01, thus weight=1.0082e+00.
# DEBUG:Acceptor:Encountered pd=-8.4229e+01 > c=-8.5612e+01, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 3382 = 2.9568e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=-5.9847e+01 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [723.4998767691575, 2375.45311010339].
# INFO:ABC:t: 1, eps: 723.4998767691575.
# DEBUG:Acceptor:Encountered pd=-5.4135e+01 > c=-5.9847e+01, thus weight=1.0079e+00.
# DEBUG:Acceptor:Encountered pd=-5.7094e+01 > c=-5.9847e+01, thus weight=1.0038e+00.
# DEBUG:Acceptor:Encountered pd=-4.7286e+01 > c=-5.9847e+01, thus weight=1.0175e+00.
# DEBUG:Acceptor:Encountered pd=-5.7357e+01 > c=-5.9847e+01, thus weight=1.0034e+00.
# DEBUG:Acceptor:Encountered pd=-5.5157e+01 > c=-5.9847e+01, thus weight=1.0065e+00.
# INFO:ABC:Acceptance rate: 1000 / 3423 = 2.9214e-01, ESS=8.8458e+02.
# DEBUG:Acceptor:pdf_norm=-4.7286e+01 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [464.40283181095435, 542.624907576868].
# INFO:ABC:t: 2, eps: 464.40283181095435.
# DEBUG:Acceptor:Encountered pd=-4.1444e+01 > c=-4.7286e+01, thus weight=1.0127e+00.
# INFO:ABC:Acceptance rate: 1000 / 3324 = 3.0084e-01, ESS=8.4557e+02.
# DEBUG:Acceptor:pdf_norm=-4.1444e+01 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [358.03079113397797, 348.30212385821574].
# INFO:ABC:t: 3, eps: 348.30212385821574.
# DEBUG:Acceptor:Encountered pd=-3.6706e+01 > c=-4.1444e+01, thus weight=1.0137e+00.
# INFO:ABC:Acceptance rate: 1000 / 3490 = 2.8653e-01, ESS=8.2527e+02.
# DEBUG:Acceptor:pdf_norm=-3.6706e+01 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [334.2869076748341, 261.2265928936618].
# INFO:ABC:t: 4, eps: 261.2265928936618.
# INFO:ABC:Acceptance rate: 1000 / 4253 = 2.3513e-01, ESS=7.3077e+02.
# DEBUG:Acceptor:pdf_norm=-3.6706e+01 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [324.57949374555824, 195.91994467024637].
# INFO:ABC:t: 5, eps: 195.91994467024637.
# DEBUG:Acceptor:Encountered pd=-3.5462e+01 > c=-3.6706e+01, thus weight=1.0064e+00.
# INFO:ABC:Acceptance rate: 1000 / 5396 = 1.8532e-01, ESS=7.1535e+02.
# DEBUG:Acceptor:pdf_norm=-3.5462e+01 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [311.90742906698466, 146.93995850268476].
# INFO:ABC:t: 6, eps: 146.93995850268476.
# INFO:ABC:Acceptance rate: 1000 / 7008 = 1.4269e-01, ESS=7.5670e+02.
# DEBUG:Acceptor:pdf_norm=-3.5462e+01 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [272.7580406632496, 110.20496887701357].
# INFO:ABC:t: 7, eps: 110.20496887701357.
# DEBUG:Acceptor:Encountered pd=-2.6091e+01 > c=-3.5462e+01, thus weight=1.0888e+00.
# DEBUG:Acceptor:Encountered pd=-3.3000e+01 > c=-3.5462e+01, thus weight=1.0226e+00.
# INFO:ABC:Acceptance rate: 1000 / 8945 = 1.1179e-01, ESS=6.7259e+02.
# DEBUG:Acceptor:pdf_norm=-2.6091e+01 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [292.65418416733627, 82.65372665776017].
# INFO:ABC:t: 8, eps: 82.65372665776017.
# INFO:ABC:Acceptance rate: 1000 / 14054 = 7.1154e-02, ESS=7.4403e+02.
# DEBUG:Acceptor:pdf_norm=-2.6091e+01 for t=9.
# DEBUG:Epsilon:Proposed temperatures for 9: [290.57945609222827, 61.990294993320134].
# INFO:ABC:t: 9, eps: 61.990294993320134.
# INFO:ABC:Acceptance rate: 1000 / 18514 = 5.4013e-02, ESS=6.9177e+02.
# DEBUG:Acceptor:pdf_norm=-2.6091e+01 for t=10.
# DEBUG:Epsilon:Proposed temperatures for 10: [313.3040762742255, 46.4927212449901].
# INFO:ABC:t: 10, eps: 46.4927212449901.
# INFO:ABC:Acceptance rate: 1000 / 29853 = 3.3497e-02, ESS=6.8662e+02.
# DEBUG:Acceptor:pdf_norm=-2.6091e+01 for t=11.
# DEBUG:Epsilon:Proposed temperatures for 11: [361.6825690763762, 34.86954093374258].
# INFO:ABC:t: 11, eps: 34.86954093374258.
# DEBUG:Acceptor:Encountered pd=-2.3862e+01 > c=-2.6091e+01, thus weight=1.0660e+00.
# INFO:ABC:Acceptance rate: 1000 / 50452 = 1.9821e-02, ESS=7.2014e+02.
# DEBUG:Acceptor:pdf_norm=-2.3862e+01 for t=12.
# DEBUG:Epsilon:Proposed temperatures for 12: [544.4089765749362, 26.152155700306935].
# INFO:ABC:t: 12, eps: 26.152155700306935.
# INFO:ABC:Acceptance rate: 1000 / 85877 = 1.1645e-02, ESS=6.9829e+02.
# DEBUG:Acceptor:pdf_norm=-2.3862e+01 for t=13.
# DEBUG:Epsilon:Proposed temperatures for 13: [2085.5463312854395, 19.6141167752302].
# INFO:ABC:t: 13, eps: 19.6141167752302.
# DEBUG:Acceptor:Encountered pd=-2.3465e+01 > c=-2.3862e+01, thus weight=1.0204e+00.
# DEBUG:Acceptor:Encountered pd=-2.2477e+01 > c=-2.3862e+01, thus weight=1.0731e+00.
# DEBUG:Acceptor:Encountered pd=-2.0297e+01 > c=-2.3862e+01, thus weight=1.1993e+00.
# DEBUG:Acceptor:Encountered pd=-2.2531e+01 > c=-2.3862e+01, thus weight=1.0702e+00.
# INFO:ABC:Acceptance rate: 1000 / 157369 = 6.3545e-03, ESS=2.9153e+02.
# DEBUG:Acceptor:pdf_norm=-2.0297e+01 for t=14.
# INFO:Epsilon:AcceptanceRateScheme: Numerics limit temperature.
# DEBUG:Epsilon:Proposed temperatures for 14: [2.688117141816135e+43, 14.71058758142265].
# INFO:ABC:t: 14, eps: 14.71058758142265.
# DEBUG:Acceptor:Encountered pd=-1.9540e+01 > c=-2.0297e+01, thus weight=1.0528e+00.

# %%
# sequential but bad c

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"mrna_{n_t}_{succ_prob}_stochacc_badc"
    if os.path.isfile(f"{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log/log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel,
                                          log_file=f"log/log_acceptor_{fb}.json"),
        population_size=1000,
        sampler=pyabc.sampler.MulticoreEvalParallelSampler(n_procs=20, check_max_eval=True)
    )
    data = pickle.load(open(f"data/data_{n_t}_{succ_prob}.p", "rb"))[1]
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(min_acceptance_rate=1e-3)
    print()

# %%
# rejection with adaptive c (in general not applicable)

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"mrna_{n_t}_{succ_prob}_rejection"
    if os.path.isfile(f"{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log/log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(log_file=f"log/log_acceptor_{fb}.json"),
        population_size=1000,
        sampler=pyabc.sampler.MulticoreEvalParallelSampler(n_procs=20, check_max_eval=True)
    )
    data = pickle.load(open(f"data/data_{n_t}_{succ_prob}.p", "rb"))[1]
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(max_nr_populations=1, min_acceptance_rate=1e-3)
    print()

# %%
# rejection with bad (but correct) c

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"mrna_{n_t}_{succ_prob}_rejection_badc"
    if os.path.isfile(f"{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log/log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel,
                                          log_file=f"log/log_acceptor_{fb}.json"),
        population_size=1000,
    )
    data = pickle.load(open(f"data/data_{n_t}_{succ_prob}.p", "rb"))[1]
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(max_nr_populations=1, min_acceptance_rate=1e-3)
    print()

# %%
# noisy model

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"mrna_{n_t}_{succ_prob}_noisymodel"
    if os.path.isfile(f"{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model_noisy(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_distance(),
        population_size=1000,
        sampler=pyabc.sampler.MulticoreEvalParallelSampler(n_procs=20, check_max_eval=True)
    )
    data = pickle.load(open(f"data/data_{n_t}_{succ_prob}.p", "rb"))[1]
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(min_acceptance_rate=1e-3)
    print()
