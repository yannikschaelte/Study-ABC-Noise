# %%
import pyabc
from study_abc_noise.model import ConversionReactionModelVars as ModelVars
import matplotlib.pyplot as plt
import numpy as np
import os
import logging
# %matplotlib inline

# for debugging
df_logger = logging.getLogger('Distance')
df_logger.setLevel(logging.DEBUG)
df_logger = logging.getLogger('Acceptor')
df_logger.setLevel(logging.DEBUG)
df_logger = logging.getLogger('Epsilon')
df_logger.setLevel(logging.DEBUG)

arr_n_t = [3, 10, 30, 100, 300, 1000]

# create data
for n_t in arr_n_t:
    fn = f"data_{n_t}"
    if not os.path.isfile(fn):
        mv = ModelVars(n_t=n_t)
        data = mv.generate_data()
        np.save(fn, data['y'])

# %%
# proposed method

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"cr_{n_t}_stochacc"
    if os.path.isfile(f"sqlite:///{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(log_file=f"log_acceptor_{fb}.json"),
        population_size=1000,
    )
    data = {'y': np.load(f"data_{n_t}.npy")}
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run()
    print()
# Out:
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:09:36.391801, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=5.3840e+00 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [38.839564564254125].
# INFO:ABC:t: 0, eps: 38.839564564254125.
# DEBUG:Acceptor:Encountered pd=5.4776e+00 > c=5.3840e+00, thus weight=1.0024e+00.
# DEBUG:Acceptor:Encountered pd=5.5685e+00 > c=5.3840e+00, thus weight=1.0048e+00.
# DEBUG:Acceptor:Encountered pd=5.8975e+00 > c=5.3840e+00, thus weight=1.0133e+00.
# DEBUG:Acceptor:Encountered pd=5.7688e+00 > c=5.3840e+00, thus weight=1.0100e+00.
# DEBUG:Acceptor:Encountered pd=6.4022e+00 > c=5.3840e+00, thus weight=1.0266e+00.
# INFO:ABC:Acceptance rate: 1000 / 3317 = 3.0148e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=6.4022e+00 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [9.362198310419389, 19.419782282127063].
# INFO:ABC:t: 1, eps: 9.362198310419389.
# INFO:ABC:Acceptance rate: 1000 / 3308 = 3.0230e-01, ESS=9.4146e+02.
# DEBUG:Acceptor:pdf_norm=6.4022e+00 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [5.024496959284644, 4.6810991552096946].
# INFO:ABC:t: 2, eps: 4.6810991552096946.
# DEBUG:Acceptor:Encountered pd=6.4245e+00 > c=6.4022e+00, thus weight=1.0048e+00.
# INFO:ABC:Acceptance rate: 1000 / 3745 = 2.6702e-01, ESS=8.7133e+02.
# DEBUG:Acceptor:pdf_norm=6.4245e+00 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [3.976290903396143, 2.3405495776048473].
# INFO:ABC:t: 3, eps: 2.3405495776048473.
# DEBUG:Acceptor:Encountered pd=6.4265e+00 > c=6.4245e+00, thus weight=1.0008e+00.
# DEBUG:Acceptor:Encountered pd=6.4264e+00 > c=6.4245e+00, thus weight=1.0008e+00.
# INFO:ABC:Acceptance rate: 1000 / 6201 = 1.6126e-01, ESS=8.5199e+02.
# DEBUG:Acceptor:pdf_norm=6.4265e+00 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [3.2717612344570175, 1.1702747888024236].
# INFO:ABC:t: 4, eps: 1.1702747888024236.
# DEBUG:Acceptor:Encountered pd=6.4371e+00 > c=6.4265e+00, thus weight=1.0091e+00.
# DEBUG:Acceptor:Encountered pd=6.4278e+00 > c=6.4265e+00, thus weight=1.0011e+00.
# DEBUG:Acceptor:Encountered pd=6.4363e+00 > c=6.4265e+00, thus weight=1.0084e+00.
# DEBUG:Acceptor:Encountered pd=6.4361e+00 > c=6.4265e+00, thus weight=1.0083e+00.
# DEBUG:Acceptor:Encountered pd=6.4364e+00 > c=6.4265e+00, thus weight=1.0085e+00.
# DEBUG:Acceptor:Encountered pd=6.4299e+00 > c=6.4265e+00, thus weight=1.0029e+00.
# DEBUG:Acceptor:Encountered pd=6.4284e+00 > c=6.4265e+00, thus weight=1.0017e+00.
# DEBUG:Acceptor:Encountered pd=6.4343e+00 > c=6.4265e+00, thus weight=1.0067e+00.
# DEBUG:Acceptor:Encountered pd=6.4321e+00 > c=6.4265e+00, thus weight=1.0048e+00.
# DEBUG:Acceptor:Encountered pd=6.4286e+00 > c=6.4265e+00, thus weight=1.0018e+00.
# DEBUG:Acceptor:Encountered pd=6.4299e+00 > c=6.4265e+00, thus weight=1.0029e+00.
# DEBUG:Acceptor:Encountered pd=6.4270e+00 > c=6.4265e+00, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 14411 = 6.9391e-02, ESS=8.6711e+02.
# DEBUG:Acceptor:pdf_norm=6.4371e+00 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [2.1854407376229528, 0.5851373944012118].
# INFO:ABC:t: 5, eps: 1.0.
# INFO:ABC:Acceptance rate: 1000 / 7985 = 1.2523e-01, ESS=4.1724e+02.
# DEBUG:Acceptor:pdf_norm=6.4371e+00 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [2.0551227877752054, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:09:36.391801, end_time=2019-12-18 15:11:49.650298)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:11:49.758667, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=2.7199e+01 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [223.91934138397502].
# INFO:ABC:t: 0, eps: 223.91934138397502.
# DEBUG:Acceptor:Encountered pd=2.7654e+01 > c=2.7199e+01, thus weight=1.0020e+00.
# DEBUG:Acceptor:Encountered pd=2.7674e+01 > c=2.7199e+01, thus weight=1.0021e+00.
# INFO:ABC:Acceptance rate: 1000 / 3370 = 2.9674e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=2.7674e+01 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [60.376113366235806, 111.95967069198751].
# INFO:ABC:t: 1, eps: 60.376113366235806.
# DEBUG:Acceptor:Encountered pd=2.7905e+01 > c=2.7674e+01, thus weight=1.0038e+00.
# DEBUG:Acceptor:Encountered pd=2.7700e+01 > c=2.7674e+01, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 3417 = 2.9265e-01, ESS=9.3178e+02.
# DEBUG:Acceptor:pdf_norm=2.7905e+01 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [33.66993905336201, 30.188056683117903].
# INFO:ABC:t: 2, eps: 30.188056683117903.
# DEBUG:Acceptor:Encountered pd=2.7907e+01 > c=2.7905e+01, thus weight=1.0001e+00.
# DEBUG:Acceptor:Encountered pd=2.7907e+01 > c=2.7905e+01, thus weight=1.0001e+00.
# INFO:ABC:Acceptance rate: 1000 / 3636 = 2.7503e-01, ESS=8.3770e+02.
# DEBUG:Acceptor:pdf_norm=2.7907e+01 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [21.16551858822094, 15.094028341558952].
# INFO:ABC:t: 3, eps: 15.094028341558952.
# DEBUG:Acceptor:Encountered pd=2.7911e+01 > c=2.7907e+01, thus weight=1.0003e+00.
# INFO:ABC:Acceptance rate: 1000 / 4614 = 2.1673e-01, ESS=6.8944e+02.
# DEBUG:Acceptor:pdf_norm=2.7911e+01 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [13.088676097267856, 7.547014170779476].
# INFO:ABC:t: 4, eps: 7.547014170779476.
# DEBUG:Acceptor:Encountered pd=2.7921e+01 > c=2.7911e+01, thus weight=1.0013e+00.
# INFO:ABC:Acceptance rate: 1000 / 5251 = 1.9044e-01, ESS=7.5208e+02.
# DEBUG:Acceptor:pdf_norm=2.7921e+01 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [5.0332392919311495, 3.773507085389738].
# INFO:ABC:t: 5, eps: 3.773507085389738.
# INFO:ABC:Acceptance rate: 1000 / 4224 = 2.3674e-01, ESS=7.3227e+02.
# DEBUG:Acceptor:pdf_norm=2.7921e+01 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [2.2286448640535603, 1.886753542694869].
# INFO:ABC:t: 6, eps: 1.886753542694869.
# INFO:ABC:Acceptance rate: 1000 / 3792 = 2.6371e-01, ESS=7.7975e+02.
# DEBUG:Acceptor:pdf_norm=2.7921e+01 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [1.0013715107986232, 0.9433767713474345].
# INFO:ABC:t: 7, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=2.7921e+01 > c=2.7921e+01, thus weight=1.0003e+00.
# DEBUG:Acceptor:Encountered pd=2.7922e+01 > c=2.7921e+01, thus weight=1.0008e+00.
# DEBUG:Acceptor:Encountered pd=2.7921e+01 > c=2.7921e+01, thus weight=1.0008e+00.
# INFO:ABC:Acceptance rate: 1000 / 3293 = 3.0367e-01, ESS=7.9064e+02.
# DEBUG:Acceptor:pdf_norm=2.7922e+01 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:11:49.758667, end_time=2019-12-18 15:13:37.449853)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:13:37.566543, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=6.5980e+01 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [728.6598266513555].
# INFO:ABC:t: 0, eps: 728.6598266513555.
# DEBUG:Acceptor:Encountered pd=6.6630e+01 > c=6.5980e+01, thus weight=1.0009e+00.
# INFO:ABC:Acceptance rate: 1000 / 3407 = 2.9351e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=6.6630e+01 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [253.4906765903433, 364.32991332567775].
# INFO:ABC:t: 1, eps: 253.4906765903433.
# INFO:ABC:Acceptance rate: 1000 / 3224 = 3.1017e-01, ESS=9.3202e+02.
# DEBUG:Acceptor:pdf_norm=6.6630e+01 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [144.78226315121086, 126.74533829517165].
# INFO:ABC:t: 2, eps: 126.74533829517165.
# DEBUG:Acceptor:Encountered pd=6.6965e+01 > c=6.6630e+01, thus weight=1.0026e+00.
# INFO:ABC:Acceptance rate: 1000 / 3788 = 2.6399e-01, ESS=8.4194e+02.
# DEBUG:Acceptor:pdf_norm=6.6965e+01 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [103.29826601207037, 63.372669147585825].
# INFO:ABC:t: 3, eps: 63.372669147585825.
# DEBUG:Acceptor:Encountered pd=6.7001e+01 > c=6.6965e+01, thus weight=1.0006e+00.
# DEBUG:Acceptor:Encountered pd=6.7048e+01 > c=6.6965e+01, thus weight=1.0013e+00.
# DEBUG:Acceptor:Encountered pd=6.6998e+01 > c=6.6965e+01, thus weight=1.0005e+00.
# INFO:ABC:Acceptance rate: 1000 / 5347 = 1.8702e-01, ESS=8.3870e+02.
# DEBUG:Acceptor:pdf_norm=6.7048e+01 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [47.78109634908089, 31.686334573792912].
# INFO:ABC:t: 4, eps: 31.686334573792912.
# DEBUG:Acceptor:Encountered pd=6.7114e+01 > c=6.7048e+01, thus weight=1.0021e+00.
# DEBUG:Acceptor:Encountered pd=6.7144e+01 > c=6.7048e+01, thus weight=1.0031e+00.
# DEBUG:Acceptor:Encountered pd=6.7105e+01 > c=6.7048e+01, thus weight=1.0018e+00.
# DEBUG:Acceptor:Encountered pd=6.7157e+01 > c=6.7048e+01, thus weight=1.0035e+00.
# DEBUG:Acceptor:Encountered pd=6.7167e+01 > c=6.7048e+01, thus weight=1.0038e+00.
# DEBUG:Acceptor:Encountered pd=6.7125e+01 > c=6.7048e+01, thus weight=1.0025e+00.
# DEBUG:Acceptor:Encountered pd=6.7075e+01 > c=6.7048e+01, thus weight=1.0009e+00.
# DEBUG:Acceptor:Encountered pd=6.7126e+01 > c=6.7048e+01, thus weight=1.0025e+00.
# INFO:ABC:Acceptance rate: 1000 / 4677 = 2.1381e-01, ESS=7.8223e+02.
# DEBUG:Acceptor:pdf_norm=6.7167e+01 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [19.684032434481892, 15.843167286896456].
# INFO:ABC:t: 5, eps: 15.843167286896456.
# DEBUG:Acceptor:Encountered pd=6.7169e+01 > c=6.7167e+01, thus weight=1.0002e+00.
# DEBUG:Acceptor:Encountered pd=6.7167e+01 > c=6.7167e+01, thus weight=1.0000e+00.
# INFO:ABC:Acceptance rate: 1000 / 4013 = 2.4919e-01, ESS=8.1781e+02.
# DEBUG:Acceptor:pdf_norm=6.7169e+01 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [8.702750410963313, 7.921583643448228].
# INFO:ABC:t: 6, eps: 7.921583643448228.
# DEBUG:Acceptor:Encountered pd=6.7170e+01 > c=6.7169e+01, thus weight=1.0001e+00.
# DEBUG:Acceptor:Encountered pd=6.7171e+01 > c=6.7169e+01, thus weight=1.0002e+00.
# INFO:ABC:Acceptance rate: 1000 / 3539 = 2.8257e-01, ESS=6.7936e+02.
# DEBUG:Acceptor:pdf_norm=6.7171e+01 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [4.346142710248232, 3.960791821724114].
# INFO:ABC:t: 7, eps: 3.960791821724114.
# INFO:ABC:Acceptance rate: 1000 / 3536 = 2.8281e-01, ESS=7.8728e+02.
# DEBUG:Acceptor:pdf_norm=6.7171e+01 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [1.9046191647122708, 1.980395910862057].
# INFO:ABC:t: 8, eps: 1.9046191647122708.
# INFO:ABC:Acceptance rate: 1000 / 3326 = 3.0066e-01, ESS=8.5418e+02.
# DEBUG:Acceptor:pdf_norm=6.7171e+01 for t=9.
# DEBUG:Epsilon:Proposed temperatures for 9: [1.0, 0.9523095823561354].
# INFO:ABC:t: 9, eps: 1.0.
# INFO:ABC:Acceptance rate: 1000 / 3143 = 3.1817e-01, ESS=7.9023e+02.
# DEBUG:Acceptor:pdf_norm=6.7171e+01 for t=10.
# DEBUG:Epsilon:Proposed temperatures for 10: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:13:37.566543, end_time=2019-12-18 15:15:54.890125)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:15:54.999381, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=1.7926e+02 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [2474.2255005258326].
# INFO:ABC:t: 0, eps: 2474.2255005258326.
# DEBUG:Acceptor:Encountered pd=2.3485e+02 > c=1.7926e+02, thus weight=1.0227e+00.
# DEBUG:Acceptor:Encountered pd=2.1539e+02 > c=1.7926e+02, thus weight=1.0147e+00.
# DEBUG:Acceptor:Encountered pd=2.1258e+02 > c=1.7926e+02, thus weight=1.0136e+00.
# DEBUG:Acceptor:Encountered pd=2.3747e+02 > c=1.7926e+02, thus weight=1.0238e+00.
# DEBUG:Acceptor:Encountered pd=1.8083e+02 > c=1.7926e+02, thus weight=1.0006e+00.
# DEBUG:Acceptor:Encountered pd=1.8449e+02 > c=1.7926e+02, thus weight=1.0021e+00.
# DEBUG:Acceptor:Encountered pd=2.1172e+02 > c=1.7926e+02, thus weight=1.0132e+00.
# DEBUG:Acceptor:Encountered pd=2.1048e+02 > c=1.7926e+02, thus weight=1.0127e+00.
# DEBUG:Acceptor:Encountered pd=2.0648e+02 > c=1.7926e+02, thus weight=1.0111e+00.
# DEBUG:Acceptor:Encountered pd=2.4285e+02 > c=1.7926e+02, thus weight=1.0260e+00.
# DEBUG:Acceptor:Encountered pd=2.0549e+02 > c=1.7926e+02, thus weight=1.0107e+00.
# DEBUG:Acceptor:Encountered pd=2.0126e+02 > c=1.7926e+02, thus weight=1.0089e+00.
# DEBUG:Acceptor:Encountered pd=2.2753e+02 > c=1.7926e+02, thus weight=1.0197e+00.
# DEBUG:Acceptor:Encountered pd=1.9372e+02 > c=1.7926e+02, thus weight=1.0059e+00.
# DEBUG:Acceptor:Encountered pd=2.3022e+02 > c=1.7926e+02, thus weight=1.0208e+00.
# INFO:ABC:Acceptance rate: 1000 / 3467 = 2.8843e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=2.4285e+02 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [751.8269617715272, 1237.1127502629163].
# INFO:ABC:t: 1, eps: 751.8269617715272.
# DEBUG:Acceptor:Encountered pd=2.4696e+02 > c=2.4285e+02, thus weight=1.0055e+00.
# DEBUG:Acceptor:Encountered pd=2.4780e+02 > c=2.4285e+02, thus weight=1.0066e+00.
# DEBUG:Acceptor:Encountered pd=2.4790e+02 > c=2.4285e+02, thus weight=1.0067e+00.
# DEBUG:Acceptor:Encountered pd=2.4889e+02 > c=2.4285e+02, thus weight=1.0081e+00.
# DEBUG:Acceptor:Encountered pd=2.4798e+02 > c=2.4285e+02, thus weight=1.0069e+00.
# DEBUG:Acceptor:Encountered pd=2.4792e+02 > c=2.4285e+02, thus weight=1.0068e+00.
# DEBUG:Acceptor:Encountered pd=2.5136e+02 > c=2.4285e+02, thus weight=1.0114e+00.
# INFO:ABC:Acceptance rate: 1000 / 3482 = 2.8719e-01, ESS=9.3743e+02.
# DEBUG:Acceptor:pdf_norm=2.5136e+02 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [470.08144393040163, 375.9134808857636].
# INFO:ABC:t: 2, eps: 375.9134808857636.
# INFO:ABC:Acceptance rate: 1000 / 4000 = 2.5000e-01, ESS=8.6143e+02.
# DEBUG:Acceptor:pdf_norm=2.5136e+02 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [310.45292971360914, 187.9567404428818].
# INFO:ABC:t: 3, eps: 187.9567404428818.
# DEBUG:Acceptor:Encountered pd=2.5160e+02 > c=2.5136e+02, thus weight=1.0013e+00.
# DEBUG:Acceptor:Encountered pd=2.5183e+02 > c=2.5136e+02, thus weight=1.0025e+00.
# DEBUG:Acceptor:Encountered pd=2.5162e+02 > c=2.5136e+02, thus weight=1.0013e+00.
# DEBUG:Acceptor:Encountered pd=2.5176e+02 > c=2.5136e+02, thus weight=1.0021e+00.
# DEBUG:Acceptor:Encountered pd=2.5155e+02 > c=2.5136e+02, thus weight=1.0010e+00.
# INFO:ABC:Acceptance rate: 1000 / 5710 = 1.7513e-01, ESS=7.3694e+02.
# DEBUG:Acceptor:pdf_norm=2.5183e+02 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [162.9918257112512, 93.9783702214409].
# INFO:ABC:t: 4, eps: 93.9783702214409.
# DEBUG:Acceptor:Encountered pd=2.5187e+02 > c=2.5183e+02, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 5335 = 1.8744e-01, ESS=7.9495e+02.
# DEBUG:Acceptor:pdf_norm=2.5187e+02 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [62.02207719450767, 46.98918511072045].
# INFO:ABC:t: 5, eps: 46.98918511072045.
# DEBUG:Acceptor:Encountered pd=2.5191e+02 > c=2.5187e+02, thus weight=1.0008e+00.
# DEBUG:Acceptor:Encountered pd=2.5189e+02 > c=2.5187e+02, thus weight=1.0005e+00.
# INFO:ABC:Acceptance rate: 1000 / 4234 = 2.3618e-01, ESS=6.3860e+02.
# DEBUG:Acceptor:pdf_norm=2.5191e+02 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [26.95648354436905, 23.494592555360224].
# INFO:ABC:t: 6, eps: 23.494592555360224.
# INFO:ABC:Acceptance rate: 1000 / 3662 = 2.7307e-01, ESS=7.9308e+02.
# DEBUG:Acceptor:pdf_norm=2.5191e+02 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [11.260985479206143, 11.747296277680112].
# INFO:ABC:t: 7, eps: 11.260985479206143.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5191e+02, thus weight=1.0023e+00.
# DEBUG:Acceptor:Encountered pd=2.5191e+02 > c=2.5191e+02, thus weight=1.0001e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5191e+02, thus weight=1.0018e+00.
# DEBUG:Acceptor:Encountered pd=2.5191e+02 > c=2.5191e+02, thus weight=1.0005e+00.
# DEBUG:Acceptor:Encountered pd=2.5191e+02 > c=2.5191e+02, thus weight=1.0005e+00.
# INFO:ABC:Acceptance rate: 1000 / 3344 = 2.9904e-01, ESS=6.9812e+02.
# DEBUG:Acceptor:pdf_norm=2.5193e+02 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [5.635455381398143, 5.6304927396030715].
# INFO:ABC:t: 8, eps: 5.6304927396030715.
# INFO:ABC:Acceptance rate: 1000 / 3155 = 3.1696e-01, ESS=7.8891e+02.
# DEBUG:Acceptor:pdf_norm=2.5193e+02 for t=9.
# DEBUG:Epsilon:Proposed temperatures for 9: [2.7248465620972055, 2.8152463698015358].
# INFO:ABC:t: 9, eps: 2.7248465620972055.
# INFO:ABC:Acceptance rate: 1000 / 3298 = 3.0321e-01, ESS=7.9874e+02.
# DEBUG:Acceptor:pdf_norm=2.5193e+02 for t=10.
# DEBUG:Epsilon:Proposed temperatures for 10: [1.3026932142378207, 1.3624232810486028].
# INFO:ABC:t: 10, eps: 1.3026932142378207.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0015e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 3349 = 2.9860e-01, ESS=8.3744e+02.
# DEBUG:Acceptor:pdf_norm=2.5193e+02 for t=11.
# DEBUG:Epsilon:Proposed temperatures for 11: [1.0, 0.6513466071189103].
# INFO:ABC:t: 11, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0004e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0000e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0006e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0004e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0006e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0004e+00.
# DEBUG:Acceptor:Encountered pd=2.5193e+02 > c=2.5193e+02, thus weight=1.0004e+00.
# INFO:ABC:Acceptance rate: 1000 / 2295 = 4.3573e-01, ESS=5.3532e+02.
# DEBUG:Acceptor:pdf_norm=2.5193e+02 for t=12.
# DEBUG:Epsilon:Proposed temperatures for 12: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:15:54.999381, end_time=2019-12-18 15:18:58.566101)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:18:58.661809, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=5.9958e+02 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [6921.814953786857].
# INFO:ABC:t: 0, eps: 6921.814953786857.
# DEBUG:Acceptor:Encountered pd=6.3863e+02 > c=5.9958e+02, thus weight=1.0057e+00.
# DEBUG:Acceptor:Encountered pd=7.3554e+02 > c=5.9958e+02, thus weight=1.0198e+00.
# DEBUG:Acceptor:Encountered pd=7.5398e+02 > c=5.9958e+02, thus weight=1.0226e+00.
# DEBUG:Acceptor:Encountered pd=7.2112e+02 > c=5.9958e+02, thus weight=1.0177e+00.
# DEBUG:Acceptor:Encountered pd=6.8240e+02 > c=5.9958e+02, thus weight=1.0120e+00.
# DEBUG:Acceptor:Encountered pd=7.4961e+02 > c=5.9958e+02, thus weight=1.0219e+00.
# DEBUG:Acceptor:Encountered pd=7.2415e+02 > c=5.9958e+02, thus weight=1.0182e+00.
# DEBUG:Acceptor:Encountered pd=7.4373e+02 > c=5.9958e+02, thus weight=1.0210e+00.
# DEBUG:Acceptor:Encountered pd=7.5241e+02 > c=5.9958e+02, thus weight=1.0223e+00.
# DEBUG:Acceptor:Encountered pd=7.0643e+02 > c=5.9958e+02, thus weight=1.0156e+00.
# DEBUG:Acceptor:Encountered pd=6.4129e+02 > c=5.9958e+02, thus weight=1.0060e+00.
# DEBUG:Acceptor:Encountered pd=6.1982e+02 > c=5.9958e+02, thus weight=1.0029e+00.
# DEBUG:Acceptor:Encountered pd=6.2228e+02 > c=5.9958e+02, thus weight=1.0033e+00.
# INFO:ABC:Acceptance rate: 1000 / 3450 = 2.8986e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=7.5398e+02 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [2301.870252735124, 3460.9074768934283].
# INFO:ABC:t: 1, eps: 2301.870252735124.
# INFO:ABC:Acceptance rate: 1000 / 3347 = 2.9878e-01, ESS=9.2407e+02.
# DEBUG:Acceptor:pdf_norm=7.5398e+02 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [1452.721850397874, 1150.935126367562].
# INFO:ABC:t: 2, eps: 1150.935126367562.
# DEBUG:Acceptor:Encountered pd=7.5697e+02 > c=7.5398e+02, thus weight=1.0026e+00.
# INFO:ABC:Acceptance rate: 1000 / 3887 = 2.5727e-01, ESS=8.8748e+02.
# DEBUG:Acceptor:pdf_norm=7.5697e+02 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [886.7455968339744, 575.467563183781].
# INFO:ABC:t: 3, eps: 575.467563183781.
# DEBUG:Acceptor:Encountered pd=7.5738e+02 > c=7.5697e+02, thus weight=1.0007e+00.
# DEBUG:Acceptor:Encountered pd=7.5761e+02 > c=7.5697e+02, thus weight=1.0011e+00.
# INFO:ABC:Acceptance rate: 1000 / 4855 = 2.0597e-01, ESS=7.6475e+02.
# DEBUG:Acceptor:pdf_norm=7.5761e+02 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [462.59193801714054, 287.7337815918905].
# INFO:ABC:t: 4, eps: 287.7337815918905.
# DEBUG:Acceptor:Encountered pd=7.5796e+02 > c=7.5761e+02, thus weight=1.0012e+00.
# DEBUG:Acceptor:Encountered pd=7.5771e+02 > c=7.5761e+02, thus weight=1.0003e+00.
# INFO:ABC:Acceptance rate: 1000 / 4914 = 2.0350e-01, ESS=7.2683e+02.
# DEBUG:Acceptor:pdf_norm=7.5796e+02 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [189.5888440182581, 143.86689079594524].
# INFO:ABC:t: 5, eps: 143.86689079594524.
# DEBUG:Acceptor:Encountered pd=7.5797e+02 > c=7.5796e+02, thus weight=1.0001e+00.
# DEBUG:Acceptor:Encountered pd=7.5801e+02 > c=7.5796e+02, thus weight=1.0003e+00.
# INFO:ABC:Acceptance rate: 1000 / 4023 = 2.4857e-01, ESS=7.8266e+02.
# DEBUG:Acceptor:pdf_norm=7.5801e+02 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [74.90216200250734, 71.93344539797262].
# INFO:ABC:t: 6, eps: 71.93344539797262.
# DEBUG:Acceptor:Encountered pd=7.5811e+02 > c=7.5801e+02, thus weight=1.0014e+00.
# DEBUG:Acceptor:Encountered pd=7.5820e+02 > c=7.5801e+02, thus weight=1.0027e+00.
# DEBUG:Acceptor:Encountered pd=7.5811e+02 > c=7.5801e+02, thus weight=1.0015e+00.
# DEBUG:Acceptor:Encountered pd=7.5826e+02 > c=7.5801e+02, thus weight=1.0036e+00.
# DEBUG:Acceptor:Encountered pd=7.5819e+02 > c=7.5801e+02, thus weight=1.0025e+00.
# DEBUG:Acceptor:Encountered pd=7.5819e+02 > c=7.5801e+02, thus weight=1.0026e+00.
# INFO:ABC:Acceptance rate: 1000 / 3488 = 2.8670e-01, ESS=7.4172e+02.
# DEBUG:Acceptor:pdf_norm=7.5826e+02 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [39.741834576846685, 35.96672269898631].
# INFO:ABC:t: 7, eps: 35.96672269898631.
# INFO:ABC:Acceptance rate: 1000 / 3488 = 2.8670e-01, ESS=8.7252e+02.
# DEBUG:Acceptor:pdf_norm=7.5826e+02 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [17.378080211706934, 17.983361349493155].
# INFO:ABC:t: 8, eps: 17.378080211706934.
# INFO:ABC:Acceptance rate: 1000 / 3178 = 3.1466e-01, ESS=7.5349e+02.
# DEBUG:Acceptor:pdf_norm=7.5826e+02 for t=9.
# DEBUG:Epsilon:Proposed temperatures for 9: [9.646621458633732, 8.689040105853467].
# INFO:ABC:t: 9, eps: 8.689040105853467.
# DEBUG:Acceptor:Encountered pd=7.5827e+02 > c=7.5826e+02, thus weight=1.0007e+00.
# INFO:ABC:Acceptance rate: 1000 / 3719 = 2.6889e-01, ESS=8.3746e+02.
# DEBUG:Acceptor:pdf_norm=7.5827e+02 for t=10.
# DEBUG:Epsilon:Proposed temperatures for 10: [3.8703402747863316, 4.344520052926733].
# INFO:ABC:t: 10, eps: 3.8703402747863316.
# DEBUG:Acceptor:Encountered pd=7.5827e+02 > c=7.5827e+02, thus weight=1.0000e+00.
# INFO:ABC:Acceptance rate: 1000 / 3389 = 2.9507e-01, ESS=8.0986e+02.
# DEBUG:Acceptor:pdf_norm=7.5827e+02 for t=11.
# DEBUG:Epsilon:Proposed temperatures for 11: [1.7963180377115415, 1.9351701373931658].
# INFO:ABC:t: 11, eps: 1.7963180377115415.
# DEBUG:Acceptor:Encountered pd=7.5827e+02 > c=7.5827e+02, thus weight=1.0006e+00.
# INFO:ABC:Acceptance rate: 1000 / 3417 = 2.9265e-01, ESS=7.1275e+02.
# DEBUG:Acceptor:pdf_norm=7.5827e+02 for t=12.
# DEBUG:Epsilon:Proposed temperatures for 12: [1.0, 0.8981590188557708].
# INFO:ABC:t: 12, eps: 1.0.
# INFO:ABC:Acceptance rate: 1000 / 3126 = 3.1990e-01, ESS=8.3288e+02.
# DEBUG:Acceptor:pdf_norm=7.5827e+02 for t=13.
# DEBUG:Epsilon:Proposed temperatures for 13: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:18:58.661809, end_time=2019-12-18 15:23:14.950684)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:23:15.086468, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=2.2147e+03 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [28471.749609036815].
# INFO:ABC:t: 0, eps: 28471.749609036815.
# DEBUG:Acceptor:Encountered pd=2.3126e+03 > c=2.2147e+03, thus weight=1.0034e+00.
# DEBUG:Acceptor:Encountered pd=2.3322e+03 > c=2.2147e+03, thus weight=1.0041e+00.
# DEBUG:Acceptor:Encountered pd=2.3965e+03 > c=2.2147e+03, thus weight=1.0064e+00.
# DEBUG:Acceptor:Encountered pd=2.3007e+03 > c=2.2147e+03, thus weight=1.0030e+00.
# DEBUG:Acceptor:Encountered pd=2.4481e+03 > c=2.2147e+03, thus weight=1.0082e+00.
# DEBUG:Acceptor:Encountered pd=2.4260e+03 > c=2.2147e+03, thus weight=1.0074e+00.
# DEBUG:Acceptor:Encountered pd=2.2873e+03 > c=2.2147e+03, thus weight=1.0026e+00.
# INFO:ABC:Acceptance rate: 1000 / 3124 = 3.2010e-01, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=2.4481e+03 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [8888.323732002116, 14235.874804518407].
# INFO:ABC:t: 1, eps: 8888.323732002116.
# INFO:ABC:Acceptance rate: 1000 / 3225 = 3.1008e-01, ESS=9.1905e+02.
# DEBUG:Acceptor:pdf_norm=2.4481e+03 for t=2.
# DEBUG:Epsilon:Proposed temperatures for 2: [5150.422606293485, 4444.161866001058].
# INFO:ABC:t: 2, eps: 4444.161866001058.
# DEBUG:Acceptor:Encountered pd=2.4527e+03 > c=2.4481e+03, thus weight=1.0010e+00.
# DEBUG:Acceptor:Encountered pd=2.4656e+03 > c=2.4481e+03, thus weight=1.0039e+00.
# DEBUG:Acceptor:Encountered pd=2.4693e+03 > c=2.4481e+03, thus weight=1.0048e+00.
# INFO:ABC:Acceptance rate: 1000 / 3894 = 2.5681e-01, ESS=8.4165e+02.
# DEBUG:Acceptor:pdf_norm=2.4693e+03 for t=3.
# DEBUG:Epsilon:Proposed temperatures for 3: [3341.0775229707947, 2222.080933000529].
# INFO:ABC:t: 3, eps: 2222.080933000529.
# DEBUG:Acceptor:Encountered pd=2.4706e+03 > c=2.4693e+03, thus weight=1.0005e+00.
# DEBUG:Acceptor:Encountered pd=2.4700e+03 > c=2.4693e+03, thus weight=1.0003e+00.
# DEBUG:Acceptor:Encountered pd=2.4721e+03 > c=2.4693e+03, thus weight=1.0012e+00.
# INFO:ABC:Acceptance rate: 1000 / 4942 = 2.0235e-01, ESS=7.6218e+02.
# DEBUG:Acceptor:pdf_norm=2.4721e+03 for t=4.
# DEBUG:Epsilon:Proposed temperatures for 4: [1995.5940489688194, 1111.0404665002645].
# INFO:ABC:t: 4, eps: 1111.0404665002645.
# INFO:ABC:Acceptance rate: 1000 / 5543 = 1.8041e-01, ESS=8.2420e+02.
# DEBUG:Acceptor:pdf_norm=2.4721e+03 for t=5.
# DEBUG:Epsilon:Proposed temperatures for 5: [808.771994623006, 555.5202332501323].
# INFO:ABC:t: 5, eps: 555.5202332501323.
# DEBUG:Acceptor:Encountered pd=2.4722e+03 > c=2.4721e+03, thus weight=1.0002e+00.
# DEBUG:Acceptor:Encountered pd=2.4725e+03 > c=2.4721e+03, thus weight=1.0007e+00.
# INFO:ABC:Acceptance rate: 1000 / 4510 = 2.2173e-01, ESS=8.2076e+02.
# DEBUG:Acceptor:pdf_norm=2.4725e+03 for t=6.
# DEBUG:Epsilon:Proposed temperatures for 6: [306.9364462428723, 277.76011662506613].
# INFO:ABC:t: 6, eps: 277.76011662506613.
# DEBUG:Acceptor:Encountered pd=2.4729e+03 > c=2.4725e+03, thus weight=1.0015e+00.
# DEBUG:Acceptor:Encountered pd=2.4725e+03 > c=2.4725e+03, thus weight=1.0000e+00.
# INFO:ABC:Acceptance rate: 1000 / 3502 = 2.8555e-01, ESS=7.4459e+02.
# DEBUG:Acceptor:pdf_norm=2.4729e+03 for t=7.
# DEBUG:Epsilon:Proposed temperatures for 7: [132.7287628584674, 138.88005831253307].
# INFO:ABC:t: 7, eps: 132.7287628584674.
# DEBUG:Acceptor:Encountered pd=2.4729e+03 > c=2.4729e+03, thus weight=1.0000e+00.
# DEBUG:Acceptor:Encountered pd=2.4731e+03 > c=2.4729e+03, thus weight=1.0015e+00.
# DEBUG:Acceptor:Encountered pd=2.4731e+03 > c=2.4729e+03, thus weight=1.0019e+00.
# DEBUG:Acceptor:Encountered pd=2.4731e+03 > c=2.4729e+03, thus weight=1.0015e+00.
# INFO:ABC:Acceptance rate: 1000 / 3461 = 2.8893e-01, ESS=8.2670e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=8.
# DEBUG:Epsilon:Proposed temperatures for 8: [63.00722846127268, 66.3643814292337].
# INFO:ABC:t: 8, eps: 63.00722846127268.
# INFO:ABC:Acceptance rate: 1000 / 3248 = 3.0788e-01, ESS=7.1964e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=9.
# DEBUG:Epsilon:Proposed temperatures for 9: [32.119420943689164, 31.50361423063634].
# INFO:ABC:t: 9, eps: 31.50361423063634.
# INFO:ABC:Acceptance rate: 1000 / 3375 = 2.9630e-01, ESS=8.0194e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=10.
# DEBUG:Epsilon:Proposed temperatures for 10: [14.901904998157956, 15.75180711531817].
# INFO:ABC:t: 10, eps: 14.901904998157956.
# INFO:ABC:Acceptance rate: 1000 / 3261 = 3.0665e-01, ESS=8.4184e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=11.
# DEBUG:Epsilon:Proposed temperatures for 11: [7.017822239533686, 7.450952499078978].
# INFO:ABC:t: 11, eps: 7.017822239533686.
# INFO:ABC:Acceptance rate: 1000 / 3261 = 3.0665e-01, ESS=8.1454e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=12.
# DEBUG:Epsilon:Proposed temperatures for 12: [3.106984655160314, 3.508911119766843].
# INFO:ABC:t: 12, eps: 3.106984655160314.
# INFO:ABC:Acceptance rate: 1000 / 3438 = 2.9087e-01, ESS=7.2983e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=13.
# DEBUG:Epsilon:Proposed temperatures for 13: [1.4921839586322516, 1.553492327580157].
# INFO:ABC:t: 13, eps: 1.4921839586322516.
# INFO:ABC:Acceptance rate: 1000 / 3269 = 3.0590e-01, ESS=7.4838e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=14.
# DEBUG:Epsilon:Proposed temperatures for 14: [1.0, 0.7460919793161258].
# INFO:ABC:t: 14, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=2.4731e+03 > c=2.4731e+03, thus weight=1.0002e+00.
# DEBUG:Acceptor:Encountered pd=2.4731e+03 > c=2.4731e+03, thus weight=1.0007e+00.
# INFO:ABC:Acceptance rate: 1000 / 2802 = 3.5689e-01, ESS=7.3376e+02.
# DEBUG:Acceptor:pdf_norm=2.4731e+03 for t=15.
# DEBUG:Epsilon:Proposed temperatures for 15: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:23:15.086468, end_time=2019-12-18 15:32:04.890823)>

# %%
# sequential but bad c

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"cr_{n_t}_stochacc_badc"
    if os.path.isfile(f"sqlite:///{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel,
                                          log_file=f"log_acceptor_{fb}.json"),
        population_size=1000,
    )
    data = {'y': np.load(f"data_{n_t}.npy")}
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run()
    print()

# %%
# rejection with adaptive c (in general not applicable)

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"cr_{n_t}_rejection"
    if os.path.isfile(f"sqlite:///{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(log_file=f"log_acceptor_{fb}.json"),
        population_size=1000,
    )
    data = {'y': np.load(f"data_{n_t}.npy")}
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(max_nr_populations=1)
    print()
# Out:
# INFO:History:Start <ABCSMC(id=2, start_time=2019-12-18 15:53:48.428731, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=6.4102e+00 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [1.0].
# INFO:ABC:t: 0, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=6.4224e+00 > c=6.4102e+00, thus weight=1.0122e+00.
# DEBUG:Acceptor:Encountered pd=6.4112e+00 > c=6.4102e+00, thus weight=1.0010e+00.
# DEBUG:Acceptor:Encountered pd=6.4144e+00 > c=6.4102e+00, thus weight=1.0042e+00.
# DEBUG:Acceptor:Encountered pd=6.4334e+00 > c=6.4102e+00, thus weight=1.0234e+00.
# DEBUG:Acceptor:Encountered pd=6.4263e+00 > c=6.4102e+00, thus weight=1.0162e+00.
# DEBUG:Acceptor:Encountered pd=6.4300e+00 > c=6.4102e+00, thus weight=1.0199e+00.
# DEBUG:Acceptor:Encountered pd=6.4163e+00 > c=6.4102e+00, thus weight=1.0061e+00.
# DEBUG:Acceptor:Encountered pd=6.4119e+00 > c=6.4102e+00, thus weight=1.0016e+00.
# DEBUG:Acceptor:Encountered pd=6.4105e+00 > c=6.4102e+00, thus weight=1.0003e+00.
# DEBUG:Acceptor:Encountered pd=6.4201e+00 > c=6.4102e+00, thus weight=1.0099e+00.
# DEBUG:Acceptor:Encountered pd=6.4270e+00 > c=6.4102e+00, thus weight=1.0169e+00.
# INFO:ABC:Acceptance rate: 1000 / 231870 = 4.3128e-03, ESS=1.0000e+03.
# DEBUG:Acceptor:pdf_norm=6.4334e+00 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [1.0].
# INFO:History:Done <ABCSMC(id=2, start_time=2019-12-18 15:53:48.428731, end_time=2019-12-18 15:54:58.802864)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:54:59.218843, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=2.7253e+01 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [1.0].
# INFO:ABC:t: 0, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=2.7808e+01 > c=2.7253e+01, thus weight=1.7414e+00.
# DEBUG:Acceptor:Encountered pd=2.7900e+01 > c=2.7253e+01, thus weight=1.9081e+00.
# DEBUG:Acceptor:Encountered pd=2.7860e+01 > c=2.7253e+01, thus weight=1.8337e+00.
# DEBUG:Acceptor:Encountered pd=2.7611e+01 > c=2.7253e+01, thus weight=1.4299e+00.
# DEBUG:Acceptor:Encountered pd=2.7557e+01 > c=2.7253e+01, thus weight=1.3548e+00.
# DEBUG:Acceptor:Encountered pd=2.7553e+01 > c=2.7253e+01, thus weight=1.3498e+00.
# DEBUG:Acceptor:Encountered pd=2.7332e+01 > c=2.7253e+01, thus weight=1.0816e+00.
# DEBUG:Acceptor:Encountered pd=2.7332e+01 > c=2.7253e+01, thus weight=1.0812e+00.
# DEBUG:Acceptor:Encountered pd=2.7442e+01 > c=2.7253e+01, thus weight=1.2079e+00.
# DEBUG:Acceptor:Encountered pd=2.7867e+01 > c=2.7253e+01, thus weight=1.8462e+00.
# DEBUG:Acceptor:Encountered pd=2.7831e+01 > c=2.7253e+01, thus weight=1.7814e+00.
# DEBUG:Acceptor:Encountered pd=2.7472e+01 > c=2.7253e+01, thus weight=1.2448e+00.
# DEBUG:Acceptor:Encountered pd=2.7379e+01 > c=2.7253e+01, thus weight=1.1341e+00.
# DEBUG:Acceptor:Encountered pd=2.7540e+01 > c=2.7253e+01, thus weight=1.3311e+00.
# DEBUG:Acceptor:Encountered pd=2.7857e+01 > c=2.7253e+01, thus weight=1.8287e+00.
# DEBUG:Acceptor:Encountered pd=2.7520e+01 > c=2.7253e+01, thus weight=1.3058e+00.
# DEBUG:Acceptor:Encountered pd=2.7359e+01 > c=2.7253e+01, thus weight=1.1111e+00.
# DEBUG:Acceptor:Encountered pd=2.7494e+01 > c=2.7253e+01, thus weight=1.2715e+00.
# DEBUG:Acceptor:Encountered pd=2.7896e+01 > c=2.7253e+01, thus weight=1.9005e+00.
# DEBUG:Acceptor:Encountered pd=2.7728e+01 > c=2.7253e+01, thus weight=1.6072e+00.
# DEBUG:Acceptor:Encountered pd=2.7905e+01 > c=2.7253e+01, thus weight=1.9182e+00.
# DEBUG:Acceptor:Encountered pd=2.7575e+01 > c=2.7253e+01, thus weight=1.3788e+00.
# DEBUG:Acceptor:Encountered pd=2.7451e+01 > c=2.7253e+01, thus weight=1.2180e+00.
# DEBUG:Acceptor:Encountered pd=2.7296e+01 > c=2.7253e+01, thus weight=1.0436e+00.
# DEBUG:Acceptor:Encountered pd=2.7867e+01 > c=2.7253e+01, thus weight=1.8463e+00.
# DEBUG:Acceptor:Encountered pd=2.7760e+01 > c=2.7253e+01, thus weight=1.6587e+00.
# DEBUG:Acceptor:Encountered pd=2.7632e+01 > c=2.7253e+01, thus weight=1.4596e+00.
# DEBUG:Acceptor:Encountered pd=2.7818e+01 > c=2.7253e+01, thus weight=1.7594e+00.
# DEBUG:Acceptor:Encountered pd=2.7463e+01 > c=2.7253e+01, thus weight=1.2333e+00.
# DEBUG:Acceptor:Encountered pd=2.7863e+01 > c=2.7253e+01, thus weight=1.8405e+00.
# DEBUG:Acceptor:Encountered pd=2.7262e+01 > c=2.7253e+01, thus weight=1.0081e+00.
# DEBUG:Acceptor:Encountered pd=2.7874e+01 > c=2.7253e+01, thus weight=1.8605e+00.
# DEBUG:Acceptor:Encountered pd=2.7685e+01 > c=2.7253e+01, thus weight=1.5393e+00.
# DEBUG:Acceptor:Encountered pd=2.7257e+01 > c=2.7253e+01, thus weight=1.0037e+00.
# DEBUG:Acceptor:Encountered pd=2.7787e+01 > c=2.7253e+01, thus weight=1.7056e+00.
# DEBUG:Acceptor:Encountered pd=2.7379e+01 > c=2.7253e+01, thus weight=1.1333e+00.
# DEBUG:Acceptor:Encountered pd=2.7814e+01 > c=2.7253e+01, thus weight=1.7525e+00.
# DEBUG:Acceptor:Encountered pd=2.7303e+01 > c=2.7253e+01, thus weight=1.0510e+00.
# DEBUG:Acceptor:Encountered pd=2.7828e+01 > c=2.7253e+01, thus weight=1.7762e+00.
# DEBUG:Acceptor:Encountered pd=2.7768e+01 > c=2.7253e+01, thus weight=1.6730e+00.
# DEBUG:Acceptor:Encountered pd=2.7414e+01 > c=2.7253e+01, thus weight=1.1738e+00.
# DEBUG:Acceptor:Encountered pd=2.7771e+01 > c=2.7253e+01, thus weight=1.6787e+00.
# DEBUG:Acceptor:Encountered pd=2.7641e+01 > c=2.7253e+01, thus weight=1.4734e+00.
# DEBUG:Acceptor:Encountered pd=2.7654e+01 > c=2.7253e+01, thus weight=1.4929e+00.
# DEBUG:Acceptor:Encountered pd=2.7729e+01 > c=2.7253e+01, thus weight=1.6081e+00.
# DEBUG:Acceptor:Encountered pd=2.7329e+01 > c=2.7253e+01, thus weight=1.0787e+00.
# DEBUG:Acceptor:Encountered pd=2.7380e+01 > c=2.7253e+01, thus weight=1.1352e+00.
# DEBUG:Acceptor:Encountered pd=2.7423e+01 > c=2.7253e+01, thus weight=1.1843e+00.
# DEBUG:Acceptor:Encountered pd=2.7785e+01 > c=2.7253e+01, thus weight=1.7015e+00.
# DEBUG:Acceptor:Encountered pd=2.7645e+01 > c=2.7253e+01, thus weight=1.4790e+00.
# DEBUG:Acceptor:Encountered pd=2.7524e+01 > c=2.7253e+01, thus weight=1.3102e+00.
# DEBUG:Acceptor:Encountered pd=2.7356e+01 > c=2.7253e+01, thus weight=1.1077e+00.
# DEBUG:Acceptor:Encountered pd=2.7388e+01 > c=2.7253e+01, thus weight=1.1437e+00.
# DEBUG:Acceptor:Encountered pd=2.7653e+01 > c=2.7253e+01, thus weight=1.4919e+00.
# DEBUG:Acceptor:Encountered pd=2.7305e+01 > c=2.7253e+01, thus weight=1.0528e+00.
# DEBUG:Acceptor:Encountered pd=2.7726e+01 > c=2.7253e+01, thus weight=1.6047e+00.
# DEBUG:Acceptor:Encountered pd=2.7277e+01 > c=2.7253e+01, thus weight=1.0241e+00.
# DEBUG:Acceptor:Encountered pd=2.7748e+01 > c=2.7253e+01, thus weight=1.6398e+00.
# DEBUG:Acceptor:Encountered pd=2.7625e+01 > c=2.7253e+01, thus weight=1.4493e+00.
# DEBUG:Acceptor:Encountered pd=2.7853e+01 > c=2.7253e+01, thus weight=1.8206e+00.
# DEBUG:Acceptor:Encountered pd=2.7347e+01 > c=2.7253e+01, thus weight=1.0983e+00.
# DEBUG:Acceptor:Encountered pd=2.7771e+01 > c=2.7253e+01, thus weight=1.6771e+00.
# DEBUG:Acceptor:Encountered pd=2.7552e+01 > c=2.7253e+01, thus weight=1.3485e+00.
# DEBUG:Acceptor:Encountered pd=2.7350e+01 > c=2.7253e+01, thus weight=1.1015e+00.
# DEBUG:Acceptor:Encountered pd=2.7493e+01 > c=2.7253e+01, thus weight=1.2711e+00.
# DEBUG:Acceptor:Encountered pd=2.7280e+01 > c=2.7253e+01, thus weight=1.0264e+00.
# DEBUG:Acceptor:Encountered pd=2.7829e+01 > c=2.7253e+01, thus weight=1.7779e+00.
# DEBUG:Acceptor:Encountered pd=2.7458e+01 > c=2.7253e+01, thus weight=1.2270e+00.
# DEBUG:Acceptor:Encountered pd=2.7526e+01 > c=2.7253e+01, thus weight=1.3139e+00.
# DEBUG:Acceptor:Encountered pd=2.7453e+01 > c=2.7253e+01, thus weight=1.2208e+00.
# DEBUG:Acceptor:Encountered pd=2.7695e+01 > c=2.7253e+01, thus weight=1.5558e+00.
# DEBUG:Acceptor:Encountered pd=2.7921e+01 > c=2.7253e+01, thus weight=1.9491e+00.
# DEBUG:Acceptor:Encountered pd=2.7613e+01 > c=2.7253e+01, thus weight=1.4326e+00.
# DEBUG:Acceptor:Encountered pd=2.7518e+01 > c=2.7253e+01, thus weight=1.3028e+00.
# DEBUG:Acceptor:Encountered pd=2.7266e+01 > c=2.7253e+01, thus weight=1.0126e+00.
# DEBUG:Acceptor:Encountered pd=2.7672e+01 > c=2.7253e+01, thus weight=1.5196e+00.
# DEBUG:Acceptor:Encountered pd=2.7511e+01 > c=2.7253e+01, thus weight=1.2939e+00.
# DEBUG:Acceptor:Encountered pd=2.7684e+01 > c=2.7253e+01, thus weight=1.5388e+00.
# DEBUG:Acceptor:Encountered pd=2.7799e+01 > c=2.7253e+01, thus weight=1.7254e+00.
# DEBUG:Acceptor:Encountered pd=2.7524e+01 > c=2.7253e+01, thus weight=1.3106e+00.
# DEBUG:Acceptor:Encountered pd=2.7594e+01 > c=2.7253e+01, thus weight=1.4055e+00.
# DEBUG:Acceptor:Encountered pd=2.7322e+01 > c=2.7253e+01, thus weight=1.0712e+00.
# DEBUG:Acceptor:Encountered pd=2.7642e+01 > c=2.7253e+01, thus weight=1.4743e+00.
# DEBUG:Acceptor:Encountered pd=2.7567e+01 > c=2.7253e+01, thus weight=1.3684e+00.
# DEBUG:Acceptor:Encountered pd=2.7565e+01 > c=2.7253e+01, thus weight=1.3660e+00.
# DEBUG:Acceptor:Encountered pd=2.7487e+01 > c=2.7253e+01, thus weight=1.2625e+00.
# DEBUG:Acceptor:Encountered pd=2.7256e+01 > c=2.7253e+01, thus weight=1.0025e+00.
# DEBUG:Acceptor:Encountered pd=2.7517e+01 > c=2.7253e+01, thus weight=1.3019e+00.
# DEBUG:Acceptor:Encountered pd=2.7849e+01 > c=2.7253e+01, thus weight=1.8135e+00.
# DEBUG:Acceptor:Encountered pd=2.7450e+01 > c=2.7253e+01, thus weight=1.2175e+00.
# DEBUG:Acceptor:Encountered pd=2.7426e+01 > c=2.7253e+01, thus weight=1.1881e+00.
# DEBUG:Acceptor:Encountered pd=2.7749e+01 > c=2.7253e+01, thus weight=1.6414e+00.
# DEBUG:Acceptor:Encountered pd=2.7755e+01 > c=2.7253e+01, thus weight=1.6518e+00.
# DEBUG:Acceptor:Encountered pd=2.7849e+01 > c=2.7253e+01, thus weight=1.8146e+00.
# DEBUG:Acceptor:Encountered pd=2.7318e+01 > c=2.7253e+01, thus weight=1.0672e+00.
# DEBUG:Acceptor:Encountered pd=2.7647e+01 > c=2.7253e+01, thus weight=1.4817e+00.
# DEBUG:Acceptor:Encountered pd=2.7299e+01 > c=2.7253e+01, thus weight=1.0464e+00.
# DEBUG:Acceptor:Encountered pd=2.7560e+01 > c=2.7253e+01, thus weight=1.3589e+00.
# DEBUG:Acceptor:Encountered pd=2.7545e+01 > c=2.7253e+01, thus weight=1.3391e+00.
# DEBUG:Acceptor:Encountered pd=2.7400e+01 > c=2.7253e+01, thus weight=1.1581e+00.
# DEBUG:Acceptor:Encountered pd=2.7377e+01 > c=2.7253e+01, thus weight=1.1317e+00.
# DEBUG:Acceptor:Encountered pd=2.7621e+01 > c=2.7253e+01, thus weight=1.4440e+00.
# DEBUG:Acceptor:Encountered pd=2.7304e+01 > c=2.7253e+01, thus weight=1.0523e+00.
# DEBUG:Acceptor:Encountered pd=2.7536e+01 > c=2.7253e+01, thus weight=1.3262e+00.
# DEBUG:Acceptor:Encountered pd=2.7830e+01 > c=2.7253e+01, thus weight=1.7807e+00.
# DEBUG:Acceptor:Encountered pd=2.7792e+01 > c=2.7253e+01, thus weight=1.7136e+00.
# DEBUG:Acceptor:Encountered pd=2.7733e+01 > c=2.7253e+01, thus weight=1.6147e+00.
# DEBUG:Acceptor:Encountered pd=2.7892e+01 > c=2.7253e+01, thus weight=1.8933e+00.
# DEBUG:Acceptor:Encountered pd=2.7423e+01 > c=2.7253e+01, thus weight=1.1849e+00.
# DEBUG:Acceptor:Encountered pd=2.7346e+01 > c=2.7253e+01, thus weight=1.0973e+00.
# DEBUG:Acceptor:Encountered pd=2.7632e+01 > c=2.7253e+01, thus weight=1.4604e+00.
# DEBUG:Acceptor:Encountered pd=2.7802e+01 > c=2.7253e+01, thus weight=1.7315e+00.
# DEBUG:Acceptor:Encountered pd=2.7744e+01 > c=2.7253e+01, thus weight=1.6334e+00.
# DEBUG:Acceptor:Encountered pd=2.7709e+01 > c=2.7253e+01, thus weight=1.5775e+00.
# DEBUG:Acceptor:Encountered pd=2.7816e+01 > c=2.7253e+01, thus weight=1.7559e+00.
# DEBUG:Acceptor:Encountered pd=2.7665e+01 > c=2.7253e+01, thus weight=1.5096e+00.
# DEBUG:Acceptor:Encountered pd=2.7608e+01 > c=2.7253e+01, thus weight=1.4256e+00.
# DEBUG:Acceptor:Encountered pd=2.7806e+01 > c=2.7253e+01, thus weight=1.7385e+00.
# DEBUG:Acceptor:Encountered pd=2.7255e+01 > c=2.7253e+01, thus weight=1.0016e+00.
# DEBUG:Acceptor:Encountered pd=2.7602e+01 > c=2.7253e+01, thus weight=1.4176e+00.
# DEBUG:Acceptor:Encountered pd=2.7577e+01 > c=2.7253e+01, thus weight=1.3820e+00.
# DEBUG:Acceptor:Encountered pd=2.7414e+01 > c=2.7253e+01, thus weight=1.1747e+00.
# DEBUG:Acceptor:Encountered pd=2.7426e+01 > c=2.7253e+01, thus weight=1.1878e+00.
# DEBUG:Acceptor:Encountered pd=2.7339e+01 > c=2.7253e+01, thus weight=1.0896e+00.
# DEBUG:Acceptor:Encountered pd=2.7361e+01 > c=2.7253e+01, thus weight=1.1137e+00.
# DEBUG:Acceptor:Encountered pd=2.7526e+01 > c=2.7253e+01, thus weight=1.3130e+00.
# DEBUG:Acceptor:Encountered pd=2.7902e+01 > c=2.7253e+01, thus weight=1.9135e+00.
# DEBUG:Acceptor:Encountered pd=2.7524e+01 > c=2.7253e+01, thus weight=1.3111e+00.
# DEBUG:Acceptor:Encountered pd=2.7680e+01 > c=2.7253e+01, thus weight=1.5315e+00.
# DEBUG:Acceptor:Encountered pd=2.7435e+01 > c=2.7253e+01, thus weight=1.1989e+00.
# DEBUG:Acceptor:Encountered pd=2.7832e+01 > c=2.7253e+01, thus weight=1.7843e+00.
# DEBUG:Acceptor:Encountered pd=2.7447e+01 > c=2.7253e+01, thus weight=1.2138e+00.
# DEBUG:Acceptor:Encountered pd=2.7706e+01 > c=2.7253e+01, thus weight=1.5727e+00.
# DEBUG:Acceptor:Encountered pd=2.7886e+01 > c=2.7253e+01, thus weight=1.8831e+00.
# DEBUG:Acceptor:Encountered pd=2.7350e+01 > c=2.7253e+01, thus weight=1.1008e+00.
# DEBUG:Acceptor:Encountered pd=2.7632e+01 > c=2.7253e+01, thus weight=1.4604e+00.
# DEBUG:Acceptor:Encountered pd=2.7716e+01 > c=2.7253e+01, thus weight=1.5877e+00.
# DEBUG:Acceptor:Encountered pd=2.7715e+01 > c=2.7253e+01, thus weight=1.5868e+00.
# DEBUG:Acceptor:Encountered pd=2.7391e+01 > c=2.7253e+01, thus weight=1.1470e+00.
# DEBUG:Acceptor:Encountered pd=2.7358e+01 > c=2.7253e+01, thus weight=1.1106e+00.
# DEBUG:Acceptor:Encountered pd=2.7325e+01 > c=2.7253e+01, thus weight=1.0741e+00.
# DEBUG:Acceptor:Encountered pd=2.7768e+01 > c=2.7253e+01, thus weight=1.6730e+00.
# DEBUG:Acceptor:Encountered pd=2.7684e+01 > c=2.7253e+01, thus weight=1.5376e+00.
# DEBUG:Acceptor:Encountered pd=2.7479e+01 > c=2.7253e+01, thus weight=1.2536e+00.
# DEBUG:Acceptor:Encountered pd=2.7491e+01 > c=2.7253e+01, thus weight=1.2681e+00.
# DEBUG:Acceptor:Encountered pd=2.7579e+01 > c=2.7253e+01, thus weight=1.3853e+00.
# DEBUG:Acceptor:Encountered pd=2.7435e+01 > c=2.7253e+01, thus weight=1.1988e+00.
# DEBUG:Acceptor:Encountered pd=2.7891e+01 > c=2.7253e+01, thus weight=1.8923e+00.
# DEBUG:Acceptor:Encountered pd=2.7421e+01 > c=2.7253e+01, thus weight=1.1820e+00.
# DEBUG:Acceptor:Encountered pd=2.7469e+01 > c=2.7253e+01, thus weight=1.2410e+00.
# DEBUG:Acceptor:Encountered pd=2.7567e+01 > c=2.7253e+01, thus weight=1.3676e+00.
# DEBUG:Acceptor:Encountered pd=2.7670e+01 > c=2.7253e+01, thus weight=1.5169e+00.
# DEBUG:Acceptor:Encountered pd=2.7902e+01 > c=2.7253e+01, thus weight=1.9129e+00.
# DEBUG:Acceptor:Encountered pd=2.7862e+01 > c=2.7253e+01, thus weight=1.8371e+00.
# DEBUG:Acceptor:Encountered pd=2.7596e+01 > c=2.7253e+01, thus weight=1.4089e+00.
# DEBUG:Acceptor:Encountered pd=2.7442e+01 > c=2.7253e+01, thus weight=1.2074e+00.
# DEBUG:Acceptor:Encountered pd=2.7429e+01 > c=2.7253e+01, thus weight=1.1924e+00.
# DEBUG:Acceptor:Encountered pd=2.7839e+01 > c=2.7253e+01, thus weight=1.7968e+00.
# DEBUG:Acceptor:Encountered pd=2.7793e+01 > c=2.7253e+01, thus weight=1.7158e+00.
# DEBUG:Acceptor:Encountered pd=2.7711e+01 > c=2.7253e+01, thus weight=1.5806e+00.
# DEBUG:Acceptor:Encountered pd=2.7308e+01 > c=2.7253e+01, thus weight=1.0559e+00.
# DEBUG:Acceptor:Encountered pd=2.7278e+01 > c=2.7253e+01, thus weight=1.0252e+00.
# DEBUG:Acceptor:Encountered pd=2.7682e+01 > c=2.7253e+01, thus weight=1.5345e+00.
# DEBUG:Acceptor:Encountered pd=2.7686e+01 > c=2.7253e+01, thus weight=1.5409e+00.
# DEBUG:Acceptor:Encountered pd=2.7462e+01 > c=2.7253e+01, thus weight=1.2324e+00.
# DEBUG:Acceptor:Encountered pd=2.7886e+01 > c=2.7253e+01, thus weight=1.8815e+00.
# DEBUG:Acceptor:Encountered pd=2.7430e+01 > c=2.7253e+01, thus weight=1.1925e+00.
# DEBUG:Acceptor:Encountered pd=2.7866e+01 > c=2.7253e+01, thus weight=1.8448e+00.
# DEBUG:Acceptor:Encountered pd=2.7904e+01 > c=2.7253e+01, thus weight=1.9165e+00.
# DEBUG:Acceptor:Encountered pd=2.7898e+01 > c=2.7253e+01, thus weight=1.9060e+00.
# DEBUG:Acceptor:Encountered pd=2.7586e+01 > c=2.7253e+01, thus weight=1.3942e+00.
# DEBUG:Acceptor:Encountered pd=2.7843e+01 > c=2.7253e+01, thus weight=1.8027e+00.
# DEBUG:Acceptor:Encountered pd=2.7304e+01 > c=2.7253e+01, thus weight=1.0516e+00.
# DEBUG:Acceptor:Encountered pd=2.7348e+01 > c=2.7253e+01, thus weight=1.0989e+00.
# DEBUG:Acceptor:Encountered pd=2.7416e+01 > c=2.7253e+01, thus weight=1.1765e+00.
# DEBUG:Acceptor:Encountered pd=2.7796e+01 > c=2.7253e+01, thus weight=1.7202e+00.
# DEBUG:Acceptor:Encountered pd=2.7747e+01 > c=2.7253e+01, thus weight=1.6374e+00.
# DEBUG:Acceptor:Encountered pd=2.7497e+01 > c=2.7253e+01, thus weight=1.2756e+00.
# DEBUG:Acceptor:Encountered pd=2.7403e+01 > c=2.7253e+01, thus weight=1.1613e+00.
# DEBUG:Acceptor:Encountered pd=2.7274e+01 > c=2.7253e+01, thus weight=1.0205e+00.
# DEBUG:Acceptor:Encountered pd=2.7803e+01 > c=2.7253e+01, thus weight=1.7319e+00.
# DEBUG:Acceptor:Encountered pd=2.7316e+01 > c=2.7253e+01, thus weight=1.0648e+00.
# DEBUG:Acceptor:Encountered pd=2.7839e+01 > c=2.7253e+01, thus weight=1.7956e+00.
# DEBUG:Acceptor:Encountered pd=2.7382e+01 > c=2.7253e+01, thus weight=1.1374e+00.
# DEBUG:Acceptor:Encountered pd=2.7760e+01 > c=2.7253e+01, thus weight=1.6599e+00.
# DEBUG:Acceptor:Encountered pd=2.7805e+01 > c=2.7253e+01, thus weight=1.7361e+00.
# DEBUG:Acceptor:Encountered pd=2.7740e+01 > c=2.7253e+01, thus weight=1.6266e+00.
# DEBUG:Acceptor:Encountered pd=2.7409e+01 > c=2.7253e+01, thus weight=1.1680e+00.
# DEBUG:Acceptor:Encountered pd=2.7870e+01 > c=2.7253e+01, thus weight=1.8519e+00.
# DEBUG:Acceptor:Encountered pd=2.7294e+01 > c=2.7253e+01, thus weight=1.0411e+00.
# DEBUG:Acceptor:Encountered pd=2.7290e+01 > c=2.7253e+01, thus weight=1.0370e+00.
# DEBUG:Acceptor:Encountered pd=2.7511e+01 > c=2.7253e+01, thus weight=1.2932e+00.
# DEBUG:Acceptor:Encountered pd=2.7485e+01 > c=2.7253e+01, thus weight=1.2602e+00.
# DEBUG:Acceptor:Encountered pd=2.7668e+01 > c=2.7253e+01, thus weight=1.5134e+00.
# DEBUG:Acceptor:Encountered pd=2.7356e+01 > c=2.7253e+01, thus weight=1.1085e+00.
# DEBUG:Acceptor:Encountered pd=2.7378e+01 > c=2.7253e+01, thus weight=1.1321e+00.
# DEBUG:Acceptor:Encountered pd=2.7390e+01 > c=2.7253e+01, thus weight=1.1458e+00.
# DEBUG:Acceptor:Encountered pd=2.7642e+01 > c=2.7253e+01, thus weight=1.4749e+00.
# DEBUG:Acceptor:Encountered pd=2.7296e+01 > c=2.7253e+01, thus weight=1.0436e+00.
# DEBUG:Acceptor:Encountered pd=2.7889e+01 > c=2.7253e+01, thus weight=1.8874e+00.
# DEBUG:Acceptor:Encountered pd=2.7370e+01 > c=2.7253e+01, thus weight=1.1239e+00.
# DEBUG:Acceptor:Encountered pd=2.7438e+01 > c=2.7253e+01, thus weight=1.2032e+00.
# DEBUG:Acceptor:Encountered pd=2.7292e+01 > c=2.7253e+01, thus weight=1.0395e+00.
# DEBUG:Acceptor:Encountered pd=2.7560e+01 > c=2.7253e+01, thus weight=1.3591e+00.
# DEBUG:Acceptor:Encountered pd=2.7452e+01 > c=2.7253e+01, thus weight=1.2201e+00.
# DEBUG:Acceptor:Encountered pd=2.7879e+01 > c=2.7253e+01, thus weight=1.8701e+00.
# DEBUG:Acceptor:Encountered pd=2.7396e+01 > c=2.7253e+01, thus weight=1.1537e+00.
# DEBUG:Acceptor:Encountered pd=2.7772e+01 > c=2.7253e+01, thus weight=1.6793e+00.
# DEBUG:Acceptor:Encountered pd=2.7893e+01 > c=2.7253e+01, thus weight=1.8955e+00.
# DEBUG:Acceptor:Encountered pd=2.7845e+01 > c=2.7253e+01, thus weight=1.8067e+00.
# DEBUG:Acceptor:Encountered pd=2.7529e+01 > c=2.7253e+01, thus weight=1.3172e+00.
# DEBUG:Acceptor:Encountered pd=2.7344e+01 > c=2.7253e+01, thus weight=1.0944e+00.
# DEBUG:Acceptor:Encountered pd=2.7274e+01 > c=2.7253e+01, thus weight=1.0209e+00.
# DEBUG:Acceptor:Encountered pd=2.7378e+01 > c=2.7253e+01, thus weight=1.1330e+00.
# DEBUG:Acceptor:Encountered pd=2.7551e+01 > c=2.7253e+01, thus weight=1.3460e+00.
# DEBUG:Acceptor:Encountered pd=2.7300e+01 > c=2.7253e+01, thus weight=1.0474e+00.
# DEBUG:Acceptor:Encountered pd=2.7483e+01 > c=2.7253e+01, thus weight=1.2582e+00.
# DEBUG:Acceptor:Encountered pd=2.7552e+01 > c=2.7253e+01, thus weight=1.3480e+00.
# DEBUG:Acceptor:Encountered pd=2.7593e+01 > c=2.7253e+01, thus weight=1.4044e+00.
# DEBUG:Acceptor:Encountered pd=2.7516e+01 > c=2.7253e+01, thus weight=1.2997e+00.
# DEBUG:Acceptor:Encountered pd=2.7510e+01 > c=2.7253e+01, thus weight=1.2921e+00.
# DEBUG:Acceptor:Encountered pd=2.7498e+01 > c=2.7253e+01, thus weight=1.2767e+00.
# DEBUG:Acceptor:Encountered pd=2.7430e+01 > c=2.7253e+01, thus weight=1.1934e+00.
# DEBUG:Acceptor:Encountered pd=2.7854e+01 > c=2.7253e+01, thus weight=1.8233e+00.
# DEBUG:Acceptor:Encountered pd=2.7368e+01 > c=2.7253e+01, thus weight=1.1218e+00.
# DEBUG:Acceptor:Encountered pd=2.7692e+01 > c=2.7253e+01, thus weight=1.5512e+00.
# DEBUG:Acceptor:Encountered pd=2.7285e+01 > c=2.7253e+01, thus weight=1.0319e+00.
# DEBUG:Acceptor:Encountered pd=2.7398e+01 > c=2.7253e+01, thus weight=1.1557e+00.
# DEBUG:Acceptor:Encountered pd=2.7292e+01 > c=2.7253e+01, thus weight=1.0397e+00.
# DEBUG:Acceptor:Encountered pd=2.7415e+01 > c=2.7253e+01, thus weight=1.1748e+00.
# DEBUG:Acceptor:Encountered pd=2.7892e+01 > c=2.7253e+01, thus weight=1.8935e+00.
# DEBUG:Acceptor:Encountered pd=2.7399e+01 > c=2.7253e+01, thus weight=1.1561e+00.
# DEBUG:Acceptor:Encountered pd=2.7759e+01 > c=2.7253e+01, thus weight=1.6573e+00.
# DEBUG:Acceptor:Encountered pd=2.7776e+01 > c=2.7253e+01, thus weight=1.6866e+00.
# DEBUG:Acceptor:Encountered pd=2.7371e+01 > c=2.7253e+01, thus weight=1.1248e+00.
# DEBUG:Acceptor:Encountered pd=2.7884e+01 > c=2.7253e+01, thus weight=1.8780e+00.
# DEBUG:Acceptor:Encountered pd=2.7746e+01 > c=2.7253e+01, thus weight=1.6367e+00.
# DEBUG:Acceptor:Encountered pd=2.7541e+01 > c=2.7253e+01, thus weight=1.3328e+00.
# DEBUG:Acceptor:Encountered pd=2.7915e+01 > c=2.7253e+01, thus weight=1.9383e+00.
# DEBUG:Acceptor:Encountered pd=2.7361e+01 > c=2.7253e+01, thus weight=1.1137e+00.
# DEBUG:Acceptor:Encountered pd=2.7439e+01 > c=2.7253e+01, thus weight=1.2037e+00.
# DEBUG:Acceptor:Encountered pd=2.7700e+01 > c=2.7253e+01, thus weight=1.5636e+00.
# DEBUG:Acceptor:Encountered pd=2.7801e+01 > c=2.7253e+01, thus weight=1.7298e+00.
# DEBUG:Acceptor:Encountered pd=2.7714e+01 > c=2.7253e+01, thus weight=1.5852e+00.
# DEBUG:Acceptor:Encountered pd=2.7622e+01 > c=2.7253e+01, thus weight=1.4461e+00.
# DEBUG:Acceptor:Encountered pd=2.7352e+01 > c=2.7253e+01, thus weight=1.1036e+00.
# DEBUG:Acceptor:Encountered pd=2.7767e+01 > c=2.7253e+01, thus weight=1.6720e+00.
# DEBUG:Acceptor:Encountered pd=2.7618e+01 > c=2.7253e+01, thus weight=1.4396e+00.
# DEBUG:Acceptor:Encountered pd=2.7447e+01 > c=2.7253e+01, thus weight=1.2132e+00.
# DEBUG:Acceptor:Encountered pd=2.7529e+01 > c=2.7253e+01, thus weight=1.3174e+00.
# DEBUG:Acceptor:Encountered pd=2.7728e+01 > c=2.7253e+01, thus weight=1.6073e+00.
# DEBUG:Acceptor:Encountered pd=2.7558e+01 > c=2.7253e+01, thus weight=1.3559e+00.
# DEBUG:Acceptor:Encountered pd=2.7377e+01 > c=2.7253e+01, thus weight=1.1319e+00.
# DEBUG:Acceptor:Encountered pd=2.7647e+01 > c=2.7253e+01, thus weight=1.4829e+00.
# DEBUG:Acceptor:Encountered pd=2.7656e+01 > c=2.7253e+01, thus weight=1.4957e+00.
# DEBUG:Acceptor:Encountered pd=2.7683e+01 > c=2.7253e+01, thus weight=1.5362e+00.
# DEBUG:Acceptor:Encountered pd=2.7408e+01 > c=2.7253e+01, thus weight=1.1676e+00.
# DEBUG:Acceptor:Encountered pd=2.7478e+01 > c=2.7253e+01, thus weight=1.2514e+00.
# DEBUG:Acceptor:Encountered pd=2.7428e+01 > c=2.7253e+01, thus weight=1.1909e+00.
# DEBUG:Acceptor:Encountered pd=2.7299e+01 > c=2.7253e+01, thus weight=1.0462e+00.
# DEBUG:Acceptor:Encountered pd=2.7643e+01 > c=2.7253e+01, thus weight=1.4766e+00.
# DEBUG:Acceptor:Encountered pd=2.7388e+01 > c=2.7253e+01, thus weight=1.1437e+00.
# DEBUG:Acceptor:Encountered pd=2.7713e+01 > c=2.7253e+01, thus weight=1.5828e+00.
# DEBUG:Acceptor:Encountered pd=2.7891e+01 > c=2.7253e+01, thus weight=1.8924e+00.
# DEBUG:Acceptor:Encountered pd=2.7813e+01 > c=2.7253e+01, thus weight=1.7502e+00.
# DEBUG:Acceptor:Encountered pd=2.7592e+01 > c=2.7253e+01, thus weight=1.4030e+00.
# DEBUG:Acceptor:Encountered pd=2.7716e+01 > c=2.7253e+01, thus weight=1.5879e+00.
# DEBUG:Acceptor:Encountered pd=2.7652e+01 > c=2.7253e+01, thus weight=1.4900e+00.
# DEBUG:Acceptor:Encountered pd=2.7385e+01 > c=2.7253e+01, thus weight=1.1410e+00.
# DEBUG:Acceptor:Encountered pd=2.7257e+01 > c=2.7253e+01, thus weight=1.0033e+00.
# DEBUG:Acceptor:Encountered pd=2.7612e+01 > c=2.7253e+01, thus weight=1.4315e+00.
# DEBUG:Acceptor:Encountered pd=2.7408e+01 > c=2.7253e+01, thus weight=1.1671e+00.
# DEBUG:Acceptor:Encountered pd=2.7529e+01 > c=2.7253e+01, thus weight=1.3175e+00.
# DEBUG:Acceptor:Encountered pd=2.7449e+01 > c=2.7253e+01, thus weight=1.2155e+00.
# DEBUG:Acceptor:Encountered pd=2.7812e+01 > c=2.7253e+01, thus weight=1.7475e+00.
# DEBUG:Acceptor:Encountered pd=2.7554e+01 > c=2.7253e+01, thus weight=1.3507e+00.
# DEBUG:Acceptor:Encountered pd=2.7378e+01 > c=2.7253e+01, thus weight=1.1326e+00.
# DEBUG:Acceptor:Encountered pd=2.7325e+01 > c=2.7253e+01, thus weight=1.0746e+00.
# DEBUG:Acceptor:Encountered pd=2.7679e+01 > c=2.7253e+01, thus weight=1.5303e+00.
# DEBUG:Acceptor:Encountered pd=2.7269e+01 > c=2.7253e+01, thus weight=1.0160e+00.
# DEBUG:Acceptor:Encountered pd=2.7296e+01 > c=2.7253e+01, thus weight=1.0431e+00.
# DEBUG:Acceptor:Encountered pd=2.7751e+01 > c=2.7253e+01, thus weight=1.6449e+00.
# DEBUG:Acceptor:Encountered pd=2.7639e+01 > c=2.7253e+01, thus weight=1.4710e+00.
# DEBUG:Acceptor:Encountered pd=2.7632e+01 > c=2.7253e+01, thus weight=1.4601e+00.
# DEBUG:Acceptor:Encountered pd=2.7325e+01 > c=2.7253e+01, thus weight=1.0737e+00.
# DEBUG:Acceptor:Encountered pd=2.7555e+01 > c=2.7253e+01, thus weight=1.3514e+00.
# DEBUG:Acceptor:Encountered pd=2.7630e+01 > c=2.7253e+01, thus weight=1.4578e+00.
# DEBUG:Acceptor:Encountered pd=2.7269e+01 > c=2.7253e+01, thus weight=1.0156e+00.
# DEBUG:Acceptor:Encountered pd=2.7884e+01 > c=2.7253e+01, thus weight=1.8780e+00.
# DEBUG:Acceptor:Encountered pd=2.7890e+01 > c=2.7253e+01, thus weight=1.8892e+00.
# DEBUG:Acceptor:Encountered pd=2.7369e+01 > c=2.7253e+01, thus weight=1.1220e+00.
# DEBUG:Acceptor:Encountered pd=2.7896e+01 > c=2.7253e+01, thus weight=1.9019e+00.
# DEBUG:Acceptor:Encountered pd=2.7441e+01 > c=2.7253e+01, thus weight=1.2057e+00.
# DEBUG:Acceptor:Encountered pd=2.7796e+01 > c=2.7253e+01, thus weight=1.7211e+00.
# DEBUG:Acceptor:Encountered pd=2.7500e+01 > c=2.7253e+01, thus weight=1.2799e+00.
# DEBUG:Acceptor:Encountered pd=2.7647e+01 > c=2.7253e+01, thus weight=1.4822e+00.
# DEBUG:Acceptor:Encountered pd=2.7730e+01 > c=2.7253e+01, thus weight=1.6110e+00.
# DEBUG:Acceptor:Encountered pd=2.7804e+01 > c=2.7253e+01, thus weight=1.7340e+00.
# DEBUG:Acceptor:Encountered pd=2.7538e+01 > c=2.7253e+01, thus weight=1.3294e+00.
# DEBUG:Acceptor:Encountered pd=2.7497e+01 > c=2.7253e+01, thus weight=1.2754e+00.
# DEBUG:Acceptor:Encountered pd=2.7290e+01 > c=2.7253e+01, thus weight=1.0368e+00.
# DEBUG:Acceptor:Encountered pd=2.7770e+01 > c=2.7253e+01, thus weight=1.6762e+00.
# DEBUG:Acceptor:Encountered pd=2.7636e+01 > c=2.7253e+01, thus weight=1.4653e+00.
# DEBUG:Acceptor:Encountered pd=2.7749e+01 > c=2.7253e+01, thus weight=1.6418e+00.
# DEBUG:Acceptor:Encountered pd=2.7450e+01 > c=2.7253e+01, thus weight=1.2170e+00.
# DEBUG:Acceptor:Encountered pd=2.7468e+01 > c=2.7253e+01, thus weight=1.2394e+00.
# DEBUG:Acceptor:Encountered pd=2.7863e+01 > c=2.7253e+01, thus weight=1.8404e+00.
# DEBUG:Acceptor:Encountered pd=2.7773e+01 > c=2.7253e+01, thus weight=1.6812e+00.
# DEBUG:Acceptor:Encountered pd=2.7666e+01 > c=2.7253e+01, thus weight=1.5104e+00.
# DEBUG:Acceptor:Encountered pd=2.7688e+01 > c=2.7253e+01, thus weight=1.5443e+00.
# DEBUG:Acceptor:Encountered pd=2.7696e+01 > c=2.7253e+01, thus weight=1.5574e+00.
# DEBUG:Acceptor:Encountered pd=2.7771e+01 > c=2.7253e+01, thus weight=1.6775e+00.
# DEBUG:Acceptor:Encountered pd=2.7758e+01 > c=2.7253e+01, thus weight=1.6563e+00.
# DEBUG:Acceptor:Encountered pd=2.7521e+01 > c=2.7253e+01, thus weight=1.3072e+00.
# DEBUG:Acceptor:Encountered pd=2.7869e+01 > c=2.7253e+01, thus weight=1.8512e+00.
# DEBUG:Acceptor:Encountered pd=2.7332e+01 > c=2.7253e+01, thus weight=1.0821e+00.
# DEBUG:Acceptor:Encountered pd=2.7656e+01 > c=2.7253e+01, thus weight=1.4954e+00.
# DEBUG:Acceptor:Encountered pd=2.7559e+01 > c=2.7253e+01, thus weight=1.3570e+00.
# DEBUG:Acceptor:Encountered pd=2.7537e+01 > c=2.7253e+01, thus weight=1.3282e+00.
# DEBUG:Acceptor:Encountered pd=2.7464e+01 > c=2.7253e+01, thus weight=1.2343e+00.
# DEBUG:Acceptor:Encountered pd=2.7509e+01 > c=2.7253e+01, thus weight=1.2911e+00.
# DEBUG:Acceptor:Encountered pd=2.7480e+01 > c=2.7253e+01, thus weight=1.2542e+00.
# DEBUG:Acceptor:Encountered pd=2.7662e+01 > c=2.7253e+01, thus weight=1.5039e+00.
# DEBUG:Acceptor:Encountered pd=2.7538e+01 > c=2.7253e+01, thus weight=1.3297e+00.
# DEBUG:Acceptor:Encountered pd=2.7542e+01 > c=2.7253e+01, thus weight=1.3349e+00.
# DEBUG:Acceptor:Encountered pd=2.7356e+01 > c=2.7253e+01, thus weight=1.1082e+00.
# DEBUG:Acceptor:Encountered pd=2.7655e+01 > c=2.7253e+01, thus weight=1.4948e+00.
# DEBUG:Acceptor:Encountered pd=2.7547e+01 > c=2.7253e+01, thus weight=1.3407e+00.
# DEBUG:Acceptor:Encountered pd=2.7724e+01 > c=2.7253e+01, thus weight=1.6005e+00.
# DEBUG:Acceptor:Encountered pd=2.7406e+01 > c=2.7253e+01, thus weight=1.1643e+00.
# DEBUG:Acceptor:Encountered pd=2.7416e+01 > c=2.7253e+01, thus weight=1.1764e+00.
# DEBUG:Acceptor:Encountered pd=2.7659e+01 > c=2.7253e+01, thus weight=1.5008e+00.
# DEBUG:Acceptor:Encountered pd=2.7449e+01 > c=2.7253e+01, thus weight=1.2164e+00.
# DEBUG:Acceptor:Encountered pd=2.7899e+01 > c=2.7253e+01, thus weight=1.9063e+00.
# DEBUG:Acceptor:Encountered pd=2.7359e+01 > c=2.7253e+01, thus weight=1.1117e+00.
# DEBUG:Acceptor:Encountered pd=2.7733e+01 > c=2.7253e+01, thus weight=1.6149e+00.
# DEBUG:Acceptor:Encountered pd=2.7763e+01 > c=2.7253e+01, thus weight=1.6646e+00.
# DEBUG:Acceptor:Encountered pd=2.7684e+01 > c=2.7253e+01, thus weight=1.5380e+00.
# DEBUG:Acceptor:Encountered pd=2.7593e+01 > c=2.7253e+01, thus weight=1.4049e+00.
# DEBUG:Acceptor:Encountered pd=2.7347e+01 > c=2.7253e+01, thus weight=1.0979e+00.
# DEBUG:Acceptor:Encountered pd=2.7828e+01 > c=2.7253e+01, thus weight=1.7765e+00.
# DEBUG:Acceptor:Encountered pd=2.7502e+01 > c=2.7253e+01, thus weight=1.2816e+00.
# DEBUG:Acceptor:Encountered pd=2.7267e+01 > c=2.7253e+01, thus weight=1.0133e+00.
# DEBUG:Acceptor:Encountered pd=2.7510e+01 > c=2.7253e+01, thus weight=1.2925e+00.
# DEBUG:Acceptor:Encountered pd=2.7787e+01 > c=2.7253e+01, thus weight=1.7052e+00.
# DEBUG:Acceptor:Encountered pd=2.7837e+01 > c=2.7253e+01, thus weight=1.7926e+00.
# DEBUG:Acceptor:Encountered pd=2.7705e+01 > c=2.7253e+01, thus weight=1.5714e+00.
# DEBUG:Acceptor:Encountered pd=2.7346e+01 > c=2.7253e+01, thus weight=1.0970e+00.
# DEBUG:Acceptor:Encountered pd=2.7667e+01 > c=2.7253e+01, thus weight=1.5127e+00.
# DEBUG:Acceptor:Encountered pd=2.7357e+01 > c=2.7253e+01, thus weight=1.1090e+00.
# DEBUG:Acceptor:Encountered pd=2.7289e+01 > c=2.7253e+01, thus weight=1.0360e+00.
# DEBUG:Acceptor:Encountered pd=2.7770e+01 > c=2.7253e+01, thus weight=1.6760e+00.
# DEBUG:Acceptor:Encountered pd=2.7616e+01 > c=2.7253e+01, thus weight=1.4367e+00.
# DEBUG:Acceptor:Encountered pd=2.7914e+01 > c=2.7253e+01, thus weight=1.9355e+00.
# DEBUG:Acceptor:Encountered pd=2.7768e+01 > c=2.7253e+01, thus weight=1.6725e+00.
# DEBUG:Acceptor:Encountered pd=2.7869e+01 > c=2.7253e+01, thus weight=1.8499e+00.
# DEBUG:Acceptor:Encountered pd=2.7660e+01 > c=2.7253e+01, thus weight=1.5009e+00.
# DEBUG:Acceptor:Encountered pd=2.7775e+01 > c=2.7253e+01, thus weight=1.6852e+00.
# DEBUG:Acceptor:Encountered pd=2.7740e+01 > c=2.7253e+01, thus weight=1.6269e+00.
# DEBUG:Acceptor:Encountered pd=2.7648e+01 > c=2.7253e+01, thus weight=1.4843e+00.
# DEBUG:Acceptor:Encountered pd=2.7296e+01 > c=2.7253e+01, thus weight=1.0434e+00.
# DEBUG:Acceptor:Encountered pd=2.7916e+01 > c=2.7253e+01, thus weight=1.9405e+00.
# DEBUG:Acceptor:Encountered pd=2.7371e+01 > c=2.7253e+01, thus weight=1.1252e+00.
# DEBUG:Acceptor:Encountered pd=2.7551e+01 > c=2.7253e+01, thus weight=1.3461e+00.
# DEBUG:Acceptor:Encountered pd=2.7374e+01 > c=2.7253e+01, thus weight=1.1281e+00.
# DEBUG:Acceptor:Encountered pd=2.7845e+01 > c=2.7253e+01, thus weight=1.8069e+00.
# DEBUG:Acceptor:Encountered pd=2.7836e+01 > c=2.7253e+01, thus weight=1.7904e+00.
# DEBUG:Acceptor:Encountered pd=2.7520e+01 > c=2.7253e+01, thus weight=1.3048e+00.
# DEBUG:Acceptor:Encountered pd=2.7550e+01 > c=2.7253e+01, thus weight=1.3449e+00.
# DEBUG:Acceptor:Encountered pd=2.7588e+01 > c=2.7253e+01, thus weight=1.3966e+00.
# DEBUG:Acceptor:Encountered pd=2.7382e+01 > c=2.7253e+01, thus weight=1.1369e+00.
# DEBUG:Acceptor:Encountered pd=2.7733e+01 > c=2.7253e+01, thus weight=1.6153e+00.
# DEBUG:Acceptor:Encountered pd=2.7880e+01 > c=2.7253e+01, thus weight=1.8707e+00.
# DEBUG:Acceptor:Encountered pd=2.7299e+01 > c=2.7253e+01, thus weight=1.0465e+00.
# DEBUG:Acceptor:Encountered pd=2.7740e+01 > c=2.7253e+01, thus weight=1.6265e+00.
# DEBUG:Acceptor:Encountered pd=2.7583e+01 > c=2.7253e+01, thus weight=1.3897e+00.
# DEBUG:Acceptor:Encountered pd=2.7819e+01 > c=2.7253e+01, thus weight=1.7597e+00.
# DEBUG:Acceptor:Encountered pd=2.7763e+01 > c=2.7253e+01, thus weight=1.6644e+00.
# DEBUG:Acceptor:Encountered pd=2.7750e+01 > c=2.7253e+01, thus weight=1.6423e+00.
# DEBUG:Acceptor:Encountered pd=2.7278e+01 > c=2.7253e+01, thus weight=1.0252e+00.
# DEBUG:Acceptor:Encountered pd=2.7875e+01 > c=2.7253e+01, thus weight=1.8617e+00.
# DEBUG:Acceptor:Encountered pd=2.7837e+01 > c=2.7253e+01, thus weight=1.7918e+00.
# DEBUG:Acceptor:Encountered pd=2.7519e+01 > c=2.7253e+01, thus weight=1.3045e+00.
# DEBUG:Acceptor:Encountered pd=2.7771e+01 > c=2.7253e+01, thus weight=1.6786e+00.
# DEBUG:Acceptor:Encountered pd=2.7619e+01 > c=2.7253e+01, thus weight=1.4408e+00.
# DEBUG:Acceptor:Encountered pd=2.7849e+01 > c=2.7253e+01, thus weight=1.8143e+00.
# DEBUG:Acceptor:Encountered pd=2.7741e+01 > c=2.7253e+01, thus weight=1.6284e+00.
# DEBUG:Acceptor:Encountered pd=2.7326e+01 > c=2.7253e+01, thus weight=1.0752e+00.
# DEBUG:Acceptor:Encountered pd=2.7386e+01 > c=2.7253e+01, thus weight=1.1413e+00.
# DEBUG:Acceptor:Encountered pd=2.7675e+01 > c=2.7253e+01, thus weight=1.5245e+00.
# DEBUG:Acceptor:Encountered pd=2.7756e+01 > c=2.7253e+01, thus weight=1.6525e+00.
# DEBUG:Acceptor:Encountered pd=2.7420e+01 > c=2.7253e+01, thus weight=1.1813e+00.
# INFO:ABC:Acceptance rate: 1000 / 623561 = 1.6037e-03, ESS=9.4982e+02.
# DEBUG:Acceptor:pdf_norm=2.7921e+01 for t=1.
# DEBUG:Epsilon:Proposed temperatures for 1: [1.0].
# INFO:History:Done <ABCSMC(id=1, start_time=2019-12-18 15:54:59.218843, end_time=2019-12-18 15:58:37.022987)>
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:58:37.939432, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=6.1921e+01 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [1.0].
# INFO:ABC:t: 0, eps: 1.0.
# DEBUG:Acceptor:Encountered pd=6.3832e+01 > c=6.1921e+01, thus weight=6.7624e+00.
# DEBUG:Acceptor:Encountered pd=6.5408e+01 > c=6.1921e+01, thus weight=3.2690e+01.
# DEBUG:Acceptor:Encountered pd=6.5002e+01 > c=6.1921e+01, thus weight=2.1790e+01.
# DEBUG:Acceptor:Encountered pd=6.4213e+01 > c=6.1921e+01, thus weight=9.8985e+00.
# DEBUG:Acceptor:Encountered pd=6.6414e+01 > c=6.1921e+01, thus weight=8.9415e+01.
# DEBUG:Acceptor:Encountered pd=6.4267e+01 > c=6.1921e+01, thus weight=1.0448e+01.
# DEBUG:Acceptor:Encountered pd=6.4823e+01 > c=6.1921e+01, thus weight=1.8221e+01.
# DEBUG:Acceptor:Encountered pd=6.7137e+01 > c=6.1921e+01, thus weight=1.8417e+02.
# DEBUG:Acceptor:Encountered pd=6.4746e+01 > c=6.1921e+01, thus weight=1.6866e+01.
# DEBUG:Acceptor:Encountered pd=6.6644e+01 > c=6.1921e+01, thus weight=1.1254e+02.
# DEBUG:Acceptor:Encountered pd=6.4464e+01 > c=6.1921e+01, thus weight=1.2720e+01.
# DEBUG:Acceptor:Encountered pd=6.2629e+01 > c=6.1921e+01, thus weight=2.0296e+00.
# DEBUG:Acceptor:Encountered pd=6.6047e+01 > c=6.1921e+01, thus weight=6.1955e+01.
# DEBUG:Acceptor:Encountered pd=6.6138e+01 > c=6.1921e+01, thus weight=6.7818e+01.
# DEBUG:Acceptor:Encountered pd=6.2051e+01 > c=6.1921e+01, thus weight=1.1393e+00.
# DEBUG:Acceptor:Encountered pd=6.3786e+01 > c=6.1921e+01, thus weight=6.4598e+00.
# DEBUG:Acceptor:Encountered pd=6.2399e+01 > c=6.1921e+01, thus weight=1.6136e+00.
# DEBUG:Acceptor:Encountered pd=6.6859e+01 > c=6.1921e+01, thus weight=1.3955e+02.
# DEBUG:Acceptor:Encountered pd=6.3465e+01 > c=6.1921e+01, thus weight=4.6838e+00.
# DEBUG:Acceptor:Encountered pd=6.3393e+01 > c=6.1921e+01, thus weight=4.3604e+00.
# DEBUG:Acceptor:Encountered pd=6.3813e+01 > c=6.1921e+01, thus weight=6.6365e+00.
# DEBUG:Acceptor:Encountered pd=6.3332e+01 > c=6.1921e+01, thus weight=4.1021e+00.
# DEBUG:Acceptor:Encountered pd=6.3783e+01 > c=6.1921e+01, thus weight=6.4352e+00.
# DEBUG:Acceptor:Encountered pd=6.5327e+01 > c=6.1921e+01, thus weight=3.0143e+01.
# DEBUG:Acceptor:Encountered pd=6.5947e+01 > c=6.1921e+01, thus weight=5.6046e+01.
# DEBUG:Acceptor:Encountered pd=6.5176e+01 > c=6.1921e+01, thus weight=2.5926e+01.
# DEBUG:Acceptor:Encountered pd=6.4631e+01 > c=6.1921e+01, thus weight=1.5036e+01.
# DEBUG:Acceptor:Encountered pd=6.5484e+01 > c=6.1921e+01, thus weight=3.5262e+01.
# DEBUG:Acceptor:Encountered pd=6.6596e+01 > c=6.1921e+01, thus weight=1.0722e+02.
# DEBUG:Acceptor:Encountered pd=6.2734e+01 > c=6.1921e+01, thus weight=2.2558e+00.
# DEBUG:Acceptor:Encountered pd=6.4700e+01 > c=6.1921e+01, thus weight=1.6101e+01.
# DEBUG:Acceptor:Encountered pd=6.3620e+01 > c=6.1921e+01, thus weight=5.4668e+00.
# DEBUG:Acceptor:Encountered pd=6.4985e+01 > c=6.1921e+01, thus weight=2.1425e+01.
# DEBUG:Acceptor:Encountered pd=6.6311e+01 > c=6.1921e+01, thus weight=8.0652e+01.
# DEBUG:Acceptor:Encountered pd=6.3785e+01 > c=6.1921e+01, thus weight=6.4502e+00.
# DEBUG:Acceptor:Encountered pd=6.4159e+01 > c=6.1921e+01, thus weight=9.3774e+00.
# DEBUG:Acceptor:Encountered pd=6.6839e+01 > c=6.1921e+01, thus weight=1.3680e+02.
# DEBUG:Acceptor:Encountered pd=6.3335e+01 > c=6.1921e+01, thus weight=4.1112e+00.
# DEBUG:Acceptor:Encountered pd=6.4580e+01 > c=6.1921e+01, thus weight=1.4281e+01.
# DEBUG:Acceptor:Encountered pd=6.6827e+01 > c=6.1921e+01, thus weight=1.3507e+02.
# DEBUG:Acceptor:Encountered pd=6.5129e+01 > c=6.1921e+01, thus weight=2.4742e+01.
# DEBUG:Acceptor:Encountered pd=6.5374e+01 > c=6.1921e+01, thus weight=3.1598e+01.
# DEBUG:Acceptor:Encountered pd=6.2453e+01 > c=6.1921e+01, thus weight=1.7019e+00.
# DEBUG:Acceptor:Encountered pd=6.2575e+01 > c=6.1921e+01, thus weight=1.9230e+00.
# DEBUG:Acceptor:Encountered pd=6.6045e+01 > c=6.1921e+01, thus weight=6.1824e+01.
# DEBUG:Acceptor:Encountered pd=6.5279e+01 > c=6.1921e+01, thus weight=2.8723e+01.
# DEBUG:Acceptor:Encountered pd=6.6793e+01 > c=6.1921e+01, thus weight=1.3054e+02.
# DEBUG:Acceptor:Encountered pd=6.6623e+01 > c=6.1921e+01, thus weight=1.1016e+02.
# DEBUG:Acceptor:Encountered pd=6.6844e+01 > c=6.1921e+01, thus weight=1.3742e+02.
# DEBUG:Acceptor:Encountered pd=6.2583e+01 > c=6.1921e+01, thus weight=1.9394e+00.
# DEBUG:Acceptor:Encountered pd=6.6971e+01 > c=6.1921e+01, thus weight=1.5606e+02.
# DEBUG:Acceptor:Encountered pd=6.5169e+01 > c=6.1921e+01, thus weight=2.5738e+01.
# DEBUG:Acceptor:Encountered pd=6.6887e+01 > c=6.1921e+01, thus weight=1.4347e+02.
# DEBUG:Acceptor:Encountered pd=6.5727e+01 > c=6.1921e+01, thus weight=4.4972e+01.
# DEBUG:Acceptor:Encountered pd=6.3409e+01 > c=6.1921e+01, thus weight=4.4275e+00.
# DEBUG:Acceptor:Encountered pd=6.6579e+01 > c=6.1921e+01, thus weight=1.0547e+02.
# DEBUG:Acceptor:Encountered pd=6.4142e+01 > c=6.1921e+01, thus weight=9.2165e+00.
# DEBUG:Acceptor:Encountered pd=6.5907e+01 > c=6.1921e+01, thus weight=5.3824e+01.
# DEBUG:Acceptor:Encountered pd=6.4001e+01 > c=6.1921e+01, thus weight=8.0020e+00.
# DEBUG:Acceptor:Encountered pd=6.5212e+01 > c=6.1921e+01, thus weight=2.6878e+01.
# DEBUG:Acceptor:Encountered pd=6.3771e+01 > c=6.1921e+01, thus weight=6.3630e+00.
# DEBUG:Acceptor:Encountered pd=6.5424e+01 > c=6.1921e+01, thus weight=3.3228e+01.
# DEBUG:Acceptor:Encountered pd=6.3718e+01 > c=6.1921e+01, thus weight=6.0303e+00.
# DEBUG:Acceptor:Encountered pd=6.4295e+01 > c=6.1921e+01, thus weight=1.0742e+01.
# DEBUG:Acceptor:Encountered pd=6.3556e+01 > c=6.1921e+01, thus weight=5.1325e+00.
# DEBUG:Acceptor:Encountered pd=6.2041e+01 > c=6.1921e+01, thus weight=1.1273e+00.
# DEBUG:Acceptor:Encountered pd=6.3172e+01 > c=6.1921e+01, thus weight=3.4945e+00.
# DEBUG:Acceptor:Encountered pd=6.6547e+01 > c=6.1921e+01, thus weight=1.0213e+02.
# DEBUG:Acceptor:Encountered pd=6.4741e+01 > c=6.1921e+01, thus weight=1.6784e+01.
# DEBUG:Acceptor:Encountered pd=6.3360e+01 > c=6.1921e+01, thus weight=4.2158e+00.
# DEBUG:Acceptor:Encountered pd=6.6149e+01 > c=6.1921e+01, thus weight=6.8618e+01.
# DEBUG:Acceptor:Encountered pd=6.3288e+01 > c=6.1921e+01, thus weight=3.9235e+00.
# DEBUG:Acceptor:Encountered pd=6.6443e+01 > c=6.1921e+01, thus weight=9.2007e+01.
# DEBUG:Acceptor:Encountered pd=6.6152e+01 > c=6.1921e+01, thus weight=6.8767e+01.
# DEBUG:Acceptor:Encountered pd=6.2751e+01 > c=6.1921e+01, thus weight=2.2947e+00.
# DEBUG:Acceptor:Encountered pd=6.4708e+01 > c=6.1921e+01, thus weight=1.6238e+01.
# DEBUG:Acceptor:Encountered pd=6.3802e+01 > c=6.1921e+01, thus weight=6.5607e+00.
# DEBUG:Acceptor:Encountered pd=6.5045e+01 > c=6.1921e+01, thus weight=2.2748e+01.
# DEBUG:Acceptor:Encountered pd=6.3657e+01 > c=6.1921e+01, thus weight=5.6745e+00.
# DEBUG:Acceptor:Encountered pd=6.3608e+01 > c=6.1921e+01, thus weight=5.4053e+00.
# DEBUG:Acceptor:Encountered pd=6.3780e+01 > c=6.1921e+01, thus weight=6.4190e+00.
# DEBUG:Acceptor:Encountered pd=6.4296e+01 > c=6.1921e+01, thus weight=1.0755e+01.
# DEBUG:Acceptor:Encountered pd=6.3066e+01 > c=6.1921e+01, thus weight=3.1429e+00.
# DEBUG:Acceptor:Encountered pd=6.4464e+01 > c=6.1921e+01, thus weight=1.2715e+01.
# DEBUG:Acceptor:Encountered pd=6.6509e+01 > c=6.1921e+01, thus weight=9.8309e+01.
# DEBUG:Acceptor:Encountered pd=6.7156e+01 > c=6.1921e+01, thus weight=1.8767e+02.
# DEBUG:Acceptor:Encountered pd=6.2996e+01 > c=6.1921e+01, thus weight=2.9317e+00.
# DEBUG:Acceptor:Encountered pd=6.5131e+01 > c=6.1921e+01, thus weight=2.4775e+01.
# DEBUG:Acceptor:Encountered pd=6.2428e+01 > c=6.1921e+01, thus weight=1.6611e+00.
# DEBUG:Acceptor:Encountered pd=6.2298e+01 > c=6.1921e+01, thus weight=1.4575e+00.
# DEBUG:Acceptor:Encountered pd=6.3009e+01 > c=6.1921e+01, thus weight=2.9699e+00.
# DEBUG:Acceptor:Encountered pd=6.4162e+01 > c=6.1921e+01, thus weight=9.4085e+00.
# DEBUG:Acceptor:Encountered pd=6.3633e+01 > c=6.1921e+01, thus weight=5.5421e+00.
# DEBUG:Acceptor:Encountered pd=6.3397e+01 > c=6.1921e+01, thus weight=4.3745e+00.
# DEBUG:Acceptor:Encountered pd=6.4504e+01 > c=6.1921e+01, thus weight=1.3235e+01.
# DEBUG:Acceptor:Encountered pd=6.2740e+01 > c=6.1921e+01, thus weight=2.2691e+00.
# DEBUG:Acceptor:Encountered pd=6.4507e+01 > c=6.1921e+01, thus weight=1.3285e+01.
# DEBUG:Acceptor:Encountered pd=6.3559e+01 > c=6.1921e+01, thus weight=5.1459e+00.
# DEBUG:Acceptor:Encountered pd=6.4923e+01 > c=6.1921e+01, thus weight=2.0119e+01.
# DEBUG:Acceptor:Encountered pd=6.4389e+01 > c=6.1921e+01, thus weight=1.1801e+01.
# DEBUG:Acceptor:Encountered pd=6.1975e+01 > c=6.1921e+01, thus weight=1.0557e+00.
# DEBUG:Acceptor:Encountered pd=6.2953e+01 > c=6.1921e+01, thus weight=2.8074e+00.
# DEBUG:Acceptor:Encountered pd=6.6294e+01 > c=6.1921e+01, thus weight=7.9293e+01.
# DEBUG:Acceptor:Encountered pd=6.2884e+01 > c=6.1921e+01, thus weight=2.6195e+00.
# DEBUG:Acceptor:Encountered pd=6.6581e+01 > c=6.1921e+01, thus weight=1.0565e+02.
# DEBUG:Acceptor:Encountered pd=6.5521e+01 > c=6.1921e+01, thus weight=3.6608e+01.
# DEBUG:Acceptor:Encountered pd=6.2825e+01 > c=6.1921e+01, thus weight=2.4691e+00.
# DEBUG:Acceptor:Encountered pd=6.5584e+01 > c=6.1921e+01, thus weight=3.8970e+01.
# DEBUG:Acceptor:Encountered pd=6.4243e+01 > c=6.1921e+01, thus weight=1.0197e+01.
# DEBUG:Acceptor:Encountered pd=6.1940e+01 > c=6.1921e+01, thus weight=1.0198e+00.
# DEBUG:Acceptor:Encountered pd=6.4447e+01 > c=6.1921e+01, thus weight=1.2508e+01.
# DEBUG:Acceptor:Encountered pd=6.6972e+01 > c=6.1921e+01, thus weight=1.5615e+02.
# DEBUG:Acceptor:Encountered pd=6.4379e+01 > c=6.1921e+01, thus weight=1.1687e+01.
# DEBUG:Acceptor:Encountered pd=6.6890e+01 > c=6.1921e+01, thus weight=1.4386e+02.
# DEBUG:Acceptor:Encountered pd=6.4700e+01 > c=6.1921e+01, thus weight=1.6104e+01.
# DEBUG:Acceptor:Encountered pd=6.4722e+01 > c=6.1921e+01, thus weight=1.6461e+01.
# DEBUG:Acceptor:Encountered pd=6.4972e+01 > c=6.1921e+01, thus weight=2.1143e+01.
# DEBUG:Acceptor:Encountered pd=6.2736e+01 > c=6.1921e+01, thus weight=2.2588e+00.
# DEBUG:Acceptor:Encountered pd=6.4377e+01 > c=6.1921e+01, thus weight=1.1660e+01.
# DEBUG:Acceptor:Encountered pd=6.5713e+01 > c=6.1921e+01, thus weight=4.4347e+01.
# DEBUG:Acceptor:Encountered pd=6.7047e+01 > c=6.1921e+01, thus weight=1.6840e+02.
# DEBUG:Acceptor:Encountered pd=6.3622e+01 > c=6.1921e+01, thus weight=5.4796e+00.
# DEBUG:Acceptor:Encountered pd=6.3367e+01 > c=6.1921e+01, thus weight=4.2480e+00.
# DEBUG:Acceptor:Encountered pd=6.2260e+01 > c=6.1921e+01, thus weight=1.4031e+00.
# DEBUG:Acceptor:Encountered pd=6.5919e+01 > c=6.1921e+01, thus weight=5.4485e+01.
# DEBUG:Acceptor:Encountered pd=6.5034e+01 > c=6.1921e+01, thus weight=2.2493e+01.
# DEBUG:Acceptor:Encountered pd=6.3341e+01 > c=6.1921e+01, thus weight=4.1381e+00.
# DEBUG:Acceptor:Encountered pd=6.3673e+01 > c=6.1921e+01, thus weight=5.7660e+00.
# DEBUG:Acceptor:Encountered pd=6.2294e+01 > c=6.1921e+01, thus weight=1.4525e+00.
# DEBUG:Acceptor:Encountered pd=6.5271e+01 > c=6.1921e+01, thus weight=2.8511e+01.
# DEBUG:Acceptor:Encountered pd=6.5172e+01 > c=6.1921e+01, thus weight=2.5826e+01.
# DEBUG:Acceptor:Encountered pd=6.5894e+01 > c=6.1921e+01, thus weight=5.3151e+01.
# DEBUG:Acceptor:Encountered pd=6.3676e+01 > c=6.1921e+01, thus weight=5.7863e+00.
# DEBUG:Acceptor:Encountered pd=6.4999e+01 > c=6.1921e+01, thus weight=2.1723e+01.
# DEBUG:Acceptor:Encountered pd=6.2813e+01 > c=6.1921e+01, thus weight=2.4399e+00.
# DEBUG:Acceptor:Encountered pd=6.3022e+01 > c=6.1921e+01, thus weight=3.0080e+00.
# DEBUG:Acceptor:Encountered pd=6.4485e+01 > c=6.1921e+01, thus weight=1.2994e+01.
# DEBUG:Acceptor:Encountered pd=6.6630e+01 > c=6.1921e+01, thus weight=1.1095e+02.
# DEBUG:Acceptor:Encountered pd=6.5957e+01 > c=6.1921e+01, thus weight=5.6621e+01.
# DEBUG:Acceptor:Encountered pd=6.2059e+01 > c=6.1921e+01, thus weight=1.1477e+00.
# DEBUG:Acceptor:Encountered pd=6.5697e+01 > c=6.1921e+01, thus weight=4.3660e+01.
# DEBUG:Acceptor:Encountered pd=6.3256e+01 > c=6.1921e+01, thus weight=3.7995e+00.
# DEBUG:Acceptor:Encountered pd=6.5105e+01 > c=6.1921e+01, thus weight=2.4151e+01.
# DEBUG:Acceptor:Encountered pd=6.6152e+01 > c=6.1921e+01, thus weight=6.8764e+01.
# DEBUG:Acceptor:Encountered pd=6.3223e+01 > c=6.1921e+01, thus weight=3.6786e+00.
# DEBUG:Acceptor:Encountered pd=6.6010e+01 > c=6.1921e+01, thus weight=5.9697e+01.
# DEBUG:Acceptor:Encountered pd=6.5273e+01 > c=6.1921e+01, thus weight=2.8576e+01.
# DEBUG:Acceptor:Encountered pd=6.2652e+01 > c=6.1921e+01, thus weight=2.0775e+00.
# DEBUG:Acceptor:Encountered pd=6.3074e+01 > c=6.1921e+01, thus weight=3.1682e+00.
# DEBUG:Acceptor:Encountered pd=6.2219e+01 > c=6.1921e+01, thus weight=1.3475e+00.
# DEBUG:Acceptor:Encountered pd=6.6135e+01 > c=6.1921e+01, thus weight=6.7659e+01.
# DEBUG:Acceptor:Encountered pd=6.5967e+01 > c=6.1921e+01, thus weight=5.7160e+01.
# DEBUG:Acceptor:Encountered pd=6.5460e+01 > c=6.1921e+01, thus weight=3.4454e+01.
# DEBUG:Acceptor:Encountered pd=6.2339e+01 > c=6.1921e+01, thus weight=1.5190e+00.
# DEBUG:Acceptor:Encountered pd=6.4046e+01 > c=6.1921e+01, thus weight=8.3778e+00.
# DEBUG:Acceptor:Encountered pd=6.4080e+01 > c=6.1921e+01, thus weight=8.6639e+00.
# DEBUG:Acceptor:Encountered pd=6.2565e+01 > c=6.1921e+01, thus weight=1.9052e+00.
# DEBUG:Acceptor:Encountered pd=6.2700e+01 > c=6.1921e+01, thus weight=2.1804e+00.
# DEBUG:Acceptor:Encountered pd=6.2446e+01 > c=6.1921e+01, thus weight=1.6914e+00.
# DEBUG:Acceptor:Encountered pd=6.3620e+01 > c=6.1921e+01, thus weight=5.4704e+00.
# DEBUG:Acceptor:Encountered pd=6.3901e+01 > c=6.1921e+01, thus weight=7.2464e+00.
# DEBUG:Acceptor:Encountered pd=6.4602e+01 > c=6.1921e+01, thus weight=1.4595e+01.
# DEBUG:Acceptor:Encountered pd=6.4401e+01 > c=6.1921e+01, thus weight=1.1945e+01.
# DEBUG:Acceptor:Encountered pd=6.2706e+01 > c=6.1921e+01, thus weight=2.1918e+00.
# DEBUG:Acceptor:Encountered pd=6.5095e+01 > c=6.1921e+01, thus weight=2.3900e+01.
# DEBUG:Acceptor:Encountered pd=6.6519e+01 > c=6.1921e+01, thus weight=9.9329e+01.
# DEBUG:Acceptor:Encountered pd=6.4520e+01 > c=6.1921e+01, thus weight=1.3453e+01.
# DEBUG:Acceptor:Encountered pd=6.4472e+01 > c=6.1921e+01, thus weight=1.2821e+01.
# DEBUG:Acceptor:Encountered pd=6.5995e+01 > c=6.1921e+01, thus weight=5.8807e+01.
# DEBUG:Acceptor:Encountered pd=6.6606e+01 > c=6.1921e+01, thus weight=1.0838e+02.
# DEBUG:Acceptor:Encountered pd=6.5808e+01 > c=6.1921e+01, thus weight=4.8790e+01.
# DEBUG:Acceptor:Encountered pd=6.6521e+01 > c=6.1921e+01, thus weight=9.9463e+01.
# DEBUG:Acceptor:Encountered pd=6.4125e+01 > c=6.1921e+01, thus weight=9.0627e+00.
# ...
# DEBUG:Acceptor:Encountered pd=2.5175e+02 > c=2.4867e+02, thus weight=2.1860e+01.
# DEBUG:Acceptor:Encountered pd=2.5049e+02 > c=2.4867e+02, thus weight=6.1770e+00.
# DEBUG:Acceptor:Encountered pd=2.5042e+02 > c=2.4867e+02, thus weight=5.7604e+00.
# DEBUG:Acceptor:Encountered pd=2.4878e+02 > c=2.4867e+02, thus weight=1.1200e+00.
# DEBUG:Acceptor:Encountered pd=2.5144e+02 > c=2.4867e+02, thus weight=1.5955e+01.
# DEBUG:Acceptor:Encountered pd=2.5118e+02 > c=2.4867e+02, thus weight=1.2348e+01.
# DEBUG:Acceptor:Encountered pd=2.5175e+02 > c=2.4867e+02, thus weight=2.1732e+01.
# DEBUG:Acceptor:Encountered pd=2.5131e+02 > c=2.4867e+02, thus weight=1.4043e+01.
# DEBUG:Acceptor:Encountered pd=2.5000e+02 > c=2.4867e+02, thus weight=3.7873e+00.
# DEBUG:Acceptor:Encountered pd=2.5065e+02 > c=2.4867e+02, thus weight=7.2487e+00.
# DEBUG:Acceptor:Encountered pd=2.5025e+02 > c=2.4867e+02, thus weight=4.8457e+00.
# DEBUG:Acceptor:Encountered pd=2.4919e+02 > c=2.4867e+02, thus weight=1.6872e+00.
# DEBUG:Acceptor:Encountered pd=2.5143e+02 > c=2.4867e+02, thus weight=1.5785e+01.
# DEBUG:Acceptor:Encountered pd=2.5160e+02 > c=2.4867e+02, thus weight=1.8789e+01.
# DEBUG:Acceptor:Encountered pd=2.5141e+02 > c=2.4867e+02, thus weight=1.5469e+01.
# DEBUG:Acceptor:Encountered pd=2.5043e+02 > c=2.4867e+02, thus weight=5.7957e+00.
# DEBUG:Acceptor:Encountered pd=2.5104e+02 > c=2.4867e+02, thus weight=1.0740e+01.
# DEBUG:Acceptor:Encountered pd=2.5105e+02 > c=2.4867e+02, thus weight=1.0794e+01.
# DEBUG:Acceptor:Encountered pd=2.4981e+02 > c=2.4867e+02, thus weight=3.1163e+00.
# DEBUG:Acceptor:Encountered pd=2.4912e+02 > c=2.4867e+02, thus weight=1.5665e+00.
# DEBUG:Acceptor:Encountered pd=2.4996e+02 > c=2.4867e+02, thus weight=3.6151e+00.
# DEBUG:Acceptor:Encountered pd=2.5128e+02 > c=2.4867e+02, thus weight=1.3627e+01.
# DEBUG:Acceptor:Encountered pd=2.5160e+02 > c=2.4867e+02, thus weight=1.8785e+01.
# DEBUG:Acceptor:Encountered pd=2.5146e+02 > c=2.4867e+02, thus weight=1.6326e+01.
# DEBUG:Acceptor:Encountered pd=2.5150e+02 > c=2.4867e+02, thus weight=1.6957e+01.
# DEBUG:Acceptor:Encountered pd=2.5010e+02 > c=2.4867e+02, thus weight=4.1797e+00.
# DEBUG:Acceptor:Encountered pd=2.5129e+02 > c=2.4867e+02, thus weight=1.3709e+01.
# DEBUG:Acceptor:Encountered pd=2.4982e+02 > c=2.4867e+02, thus weight=3.1493e+00.
# DEBUG:Acceptor:Encountered pd=2.4909e+02 > c=2.4867e+02, thus weight=1.5159e+00.
# DEBUG:Acceptor:Encountered pd=2.5037e+02 > c=2.4867e+02, thus weight=5.4956e+00.
# DEBUG:Acceptor:Encountered pd=2.5143e+02 > c=2.4867e+02, thus weight=1.5732e+01.
# DEBUG:Acceptor:Encountered pd=2.4963e+02 > c=2.4867e+02, thus weight=2.6155e+00.
# DEBUG:Acceptor:Encountered pd=2.5128e+02 > c=2.4867e+02, thus weight=1.3622e+01.
# DEBUG:Acceptor:Encountered pd=2.5017e+02 > c=2.4867e+02, thus weight=4.4865e+00.
# DEBUG:Acceptor:Encountered pd=2.4919e+02 > c=2.4867e+02, thus weight=1.6791e+00.
# DEBUG:Acceptor:Encountered pd=2.5036e+02 > c=2.4867e+02, thus weight=5.4347e+00.
# DEBUG:Acceptor:Encountered pd=2.4984e+02 > c=2.4867e+02, thus weight=3.2069e+00.
# DEBUG:Acceptor:Encountered pd=2.4884e+02 > c=2.4867e+02, thus weight=1.1881e+00.
# DEBUG:Acceptor:Encountered pd=2.5177e+02 > c=2.4867e+02, thus weight=2.2298e+01.
# DEBUG:Acceptor:Encountered pd=2.4936e+02 > c=2.4867e+02, thus weight=1.9882e+00.
# DEBUG:Acceptor:Encountered pd=2.4916e+02 > c=2.4867e+02, thus weight=1.6242e+00.
# DEBUG:Acceptor:Encountered pd=2.4889e+02 > c=2.4867e+02, thus weight=1.2466e+00.
# DEBUG:Acceptor:Encountered pd=2.5159e+02 > c=2.4867e+02, thus weight=1.8583e+01.
# DEBUG:Acceptor:Encountered pd=2.4917e+02 > c=2.4867e+02, thus weight=1.6502e+00.
# DEBUG:Acceptor:Encountered pd=2.5039e+02 > c=2.4867e+02, thus weight=5.5950e+00.
# DEBUG:Acceptor:Encountered pd=2.4995e+02 > c=2.4867e+02, thus weight=3.5836e+00.
# DEBUG:Acceptor:Encountered pd=2.4914e+02 > c=2.4867e+02, thus weight=1.5944e+00.
# DEBUG:Acceptor:Encountered pd=2.4945e+02 > c=2.4867e+02, thus weight=2.1793e+00.
# DEBUG:Acceptor:Encountered pd=2.4986e+02 > c=2.4867e+02, thus weight=3.2808e+00.
# DEBUG:Acceptor:Encountered pd=2.5112e+02 > c=2.4867e+02, thus weight=1.1530e+01.
# DEBUG:Acceptor:Encountered pd=2.4962e+02 > c=2.4867e+02, thus weight=2.5817e+00.
# DEBUG:Acceptor:Encountered pd=2.5127e+02 > c=2.4867e+02, thus weight=1.3454e+01.
# DEBUG:Acceptor:Encountered pd=2.4960e+02 > c=2.4867e+02, thus weight=2.5466e+00.
# DEBUG:Acceptor:Encountered pd=2.4919e+02 > c=2.4867e+02, thus weight=1.6894e+00.
# DEBUG:Acceptor:Encountered pd=2.5021e+02 > c=2.4867e+02, thus weight=4.6472e+00.
# DEBUG:Acceptor:Encountered pd=2.5120e+02 > c=2.4867e+02, thus weight=1.2518e+01.
# DEBUG:Acceptor:Encountered pd=2.4990e+02 > c=2.4867e+02, thus weight=3.4336e+00.
# DEBUG:Acceptor:Encountered pd=2.5092e+02 > c=2.4867e+02, thus weight=9.4792e+00.
# DEBUG:Acceptor:Encountered pd=2.4965e+02 > c=2.4867e+02, thus weight=2.6515e+00.
# DEBUG:Acceptor:Encountered pd=2.5086e+02 > c=2.4867e+02, thus weight=8.9230e+00.
# DEBUG:Acceptor:Encountered pd=2.4880e+02 > c=2.4867e+02, thus weight=1.1347e+00.
# DEBUG:Acceptor:Encountered pd=2.4873e+02 > c=2.4867e+02, thus weight=1.0614e+00.
# DEBUG:Acceptor:Encountered pd=2.5179e+02 > c=2.4867e+02, thus weight=2.2648e+01.
# DEBUG:Acceptor:Encountered pd=2.5127e+02 > c=2.4867e+02, thus weight=1.3490e+01.
# DEBUG:Acceptor:Encountered pd=2.5133e+02 > c=2.4867e+02, thus weight=1.4277e+01.
# DEBUG:Acceptor:Encountered pd=2.5176e+02 > c=2.4867e+02, thus weight=2.2005e+01.
# DEBUG:Acceptor:Encountered pd=2.4897e+02 > c=2.4867e+02, thus weight=1.3487e+00.
# DEBUG:Acceptor:Encountered pd=2.5035e+02 > c=2.4867e+02, thus weight=5.3589e+00.
# DEBUG:Acceptor:Encountered pd=2.4962e+02 > c=2.4867e+02, thus weight=2.5965e+00.
# DEBUG:Acceptor:Encountered pd=2.5023e+02 > c=2.4867e+02, thus weight=4.7450e+00.
# DEBUG:Acceptor:Encountered pd=2.5179e+02 > c=2.4867e+02, thus weight=2.2603e+01.
# DEBUG:Acceptor:Encountered pd=2.4946e+02 > c=2.4867e+02, thus weight=2.1961e+00.
# DEBUG:Acceptor:Encountered pd=2.4993e+02 > c=2.4867e+02, thus weight=3.5115e+00.
# DEBUG:Acceptor:Encountered pd=2.4874e+02 > c=2.4867e+02, thus weight=1.0722e+00.
# DEBUG:Acceptor:Encountered pd=2.4900e+02 > c=2.4867e+02, thus weight=1.3963e+00.
# DEBUG:Acceptor:Encountered pd=2.4956e+02 > c=2.4867e+02, thus weight=2.4245e+00.
# DEBUG:Acceptor:Encountered pd=2.5009e+02 > c=2.4867e+02, thus weight=4.1240e+00.
# DEBUG:Acceptor:Encountered pd=2.4918e+02 > c=2.4867e+02, thus weight=1.6689e+00.
# DEBUG:Acceptor:Encountered pd=2.4981e+02 > c=2.4867e+02, thus weight=3.1249e+00.
# DEBUG:Acceptor:Encountered pd=2.4980e+02 > c=2.4867e+02, thus weight=3.0930e+00.
# DEBUG:Acceptor:Encountered pd=2.5169e+02 > c=2.4867e+02, thus weight=2.0481e+01.
# DEBUG:Acceptor:Encountered pd=2.5106e+02 > c=2.4867e+02, thus weight=1.0883e+01.
# DEBUG:Acceptor:Encountered pd=2.4998e+02 > c=2.4867e+02, thus weight=3.7148e+00.
# DEBUG:Acceptor:Encountered pd=2.5120e+02 > c=2.4867e+02, thus weight=1.2597e+01.
# DEBUG:Acceptor:Encountered pd=2.4997e+02 > c=2.4867e+02, thus weight=3.6607e+00.
# DEBUG:Acceptor:Encountered pd=2.4942e+02 > c=2.4867e+02, thus weight=2.1183e+00.
# DEBUG:Acceptor:Encountered pd=2.4917e+02 > c=2.4867e+02, thus weight=1.6554e+00.
# DEBUG:Acceptor:Encountered pd=2.5037e+02 > c=2.4867e+02, thus weight=5.4878e+00.
# DEBUG:Acceptor:Encountered pd=2.5051e+02 > c=2.4867e+02, thus weight=6.2829e+00.
# DEBUG:Acceptor:Encountered pd=2.5011e+02 > c=2.4867e+02, thus weight=4.2280e+00.
# DEBUG:Acceptor:Encountered pd=2.5044e+02 > c=2.4867e+02, thus weight=5.8887e+00.
# DEBUG:Acceptor:Encountered pd=2.5066e+02 > c=2.4867e+02, thus weight=7.3322e+00.
# DEBUG:Acceptor:Encountered pd=2.5120e+02 > c=2.4867e+02, thus weight=1.2594e+01.
# DEBUG:Acceptor:Encountered pd=2.4947e+02 > c=2.4867e+02, thus weight=2.2177e+00.
# DEBUG:Acceptor:Encountered pd=2.5092e+02 > c=2.4867e+02, thus weight=9.4970e+00.
# DEBUG:Acceptor:Encountered pd=2.4915e+02 > c=2.4867e+02, thus weight=1.6080e+00.
# DEBUG:Acceptor:Encountered pd=2.5173e+02 > c=2.4867e+02, thus weight=2.1328e+01.
# DEBUG:Acceptor:Encountered pd=2.5050e+02 > c=2.4867e+02, thus weight=6.2566e+00.
# DEBUG:Acceptor:Encountered pd=2.5157e+02 > c=2.4867e+02, thus weight=1.8122e+01.
# DEBUG:Acceptor:Encountered pd=2.5161e+02 > c=2.4867e+02, thus weight=1.8916e+01.
# DEBUG:Acceptor:Encountered pd=2.5035e+02 > c=2.4867e+02, thus weight=5.3474e+00.
# DEBUG:Acceptor:Encountered pd=2.5127e+02 > c=2.4867e+02, thus weight=1.3460e+01.
# DEBUG:Acceptor:Encountered pd=2.4975e+02 > c=2.4867e+02, thus weight=2.9580e+00.
# DEBUG:Acceptor:Encountered pd=2.5155e+02 > c=2.4867e+02, thus weight=1.7888e+01.
# DEBUG:Acceptor:Encountered pd=2.5167e+02 > c=2.4867e+02, thus weight=2.0080e+01.
# Process Process-760:
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Process-758:
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-757:
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Process-759:
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 622, in _generate_valid_proposal
#     m_ss = int(model_prior.rvs())
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/model.py", line 227, in accept
#     sum_stats_calculator)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d2b1cfa5b111> in <module>
#      14     data = {'y': np.load(f"data_{n_t}.npy")}
#      15     abc.new(f"sqlite:///{fb}.db", data)
# ---> 16     abc.run(max_nr_populations=1)
#      17     print()
#
# ~/pyabc/pyabc/smc.py in run(self, minimum_epsilon, max_nr_populations, min_acceptance_rate)
#     882             # perform the sampling
#     883             sample = self.sampler.sample_until_n_accepted(
# --> 884                 self.population_strategy.nr_particles, simulate_one)
#     885
#     886             # retrieve accepted population
#
# ~/pyabc/pyabc/sampler/base.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     143     """
#     144     def sample_until_n_accepted(self, n, simulate_one, all_accepted=False):
# --> 145         sample = f(self, n, simulate_one, all_accepted)
#     146         if sample.n_accepted != n:
#     147             raise AssertionError(
#
# ~/pyabc/pyabc/sampler/multicore_evaluation_parallel.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     115         n_done = 0
#     116         while n_done < len(processes):
# --> 117             val = get_if_worker_healthy(processes, queue)
#     118             if val == DONE:
#     119                 n_done += 1
#
# ~/pyabc/pyabc/sampler/multicorebase.py in get_if_worker_healthy(workers, queue)
#      51     while True:
#      52         try:
# ---> 53             item = queue.get(True, 5)
#      54             return item
#      55         except Empty:
#
# ~/anaconda3/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/pyabc/pyabc/model.py", line 121, in summary_statistics
#     raw_data = self.sample(pars)
#   File "/home/yannik/pyabc/pyabc/model.py", line 270, in sample
#     return self.sample_function(pars)
#   File "/home/yannik/pyabc/pyabc/model.py", line 227, in accept
#     sum_stats_calculator)
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 50, in model
#     y = x(p, self.x0, self.get_ts())[1, :]
#   File "/home/yannik/pyabc/pyabc/model.py", line 121, in summary_statistics
#     raw_data = self.sample(pars)
#   File "/home/yannik/pyabc/pyabc/model.py", line 227, in accept
#     sum_stats_calculator)
#   File "/home/yannik/pyabc/pyabc/model.py", line 270, in sample
#     return self.sample_function(pars)
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 161, in x
#     sol[:, ix] = np.dot(A, x0).flatten()
#   File "/home/yannik/pyabc/pyabc/model.py", line 121, in summary_statistics
#     raw_data = self.sample(pars)
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 50, in model
#     y = x(p, self.x0, self.get_ts())[1, :]
#   File "/home/yannik/pyabc/pyabc/model.py", line 270, in sample
#     return self.sample_function(pars)
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 50, in model
#     y = x(p, self.x0, self.get_ts())[1, :]
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 161, in x
#     sol[:, ix] = np.dot(A, x0).flatten()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 159, in x
#     A = 1 / (- p0 - p1) * np.array([[- p1 - p0 * e, - p1 + p1 * e],
# KeyboardInterrupt

# %%
# rejection with bad (but correct) c

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"cr_{n_t}_rejection_badc"
    if os.path.isfile(f"sqlite:///{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_kernel(),
        eps=pyabc.Temperature(log_file=f"log_temperature_{fb}.json"),
        acceptor=pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel,
                                          log_file=f"log_acceptor_{fb}.json"),
        population_size=1000,
    )
    data = {'y': np.load(f"data_{n_t}.npy")}
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(max_nr_populations=1)
    print()
# Out:
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:48:08.709124, end_time=None)>
# DEBUG:Acceptor:pdf_norm=8.9793e+00 for t=0.
# DEBUG:Epsilon:Proposed temperatures for 0: [1.0].
# INFO:ABC:t: 0, eps: 1.0.
# Process Process-653:
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6739336a21c3> in <module>
#      15     data = {'y': np.load(f"data_{n_t}.npy")}
#      16     abc.new(f"sqlite:///{fb}.db", data)
# ---> 17     abc.run(max_nr_populations=1)
#      18     print()
#
# ~/pyabc/pyabc/smc.py in run(self, minimum_epsilon, max_nr_populations, min_acceptance_rate)
#     882             # perform the sampling
#     883             sample = self.sampler.sample_until_n_accepted(
# --> 884                 self.population_strategy.nr_particles, simulate_one)
#     885
#     886             # retrieve accepted population
#
# ~/pyabc/pyabc/sampler/base.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     143     """
#     144     def sample_until_n_accepted(self, n, simulate_one, all_accepted=False):
# --> 145         sample = f(self, n, simulate_one, all_accepted)
#     146         if sample.n_accepted != n:
#     147             raise AssertionError(
#
# ~/pyabc/pyabc/sampler/multicore_evaluation_parallel.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     115         n_done = 0
#     116         while n_done < len(processes):
# --> 117             val = get_if_worker_healthy(processes, queue)
#     118             if val == DONE:
#     119                 n_done += 1
#
# ~/pyabc/pyabc/sampler/multicorebase.py in get_if_worker_healthy(workers, queue)
#      51     while True:
#      52         try:
# ---> 53             item = queue.get(True, 5)
#      54             return item
#      55         except Empty:
#
# ~/anaconda3/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
# Process Process-655:
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 622, in _generate_valid_proposal
#     m_ss = int(model_prior.rvs())
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 183, in rvs
#     return self.distribution.rvs(*args, **kwargs)
# Process Process-654:
# Process Process-656:
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 468, in rvs
#     return self.dist.rvs(*self.args, **kwds)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 2846, in rvs
#     return super(rv_discrete, self).rvs(*args, **kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 952, in rvs
#     vals = self._rvs(*args)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_discrete_distns.py", line 718, in _rvs
#     return randint(low, high)
#   File "/home/yannik/pyabc/pyabc/model.py", line 234, in accept
#     par=pars)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/acceptor/acceptor.py", line 441, in __call__
#     pd = kernel(x, x_0, t, par)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 2091, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 2167, in _vectorize_call
#     outputs = ufunc(*inputs)
# KeyboardInterrupt
#   File "/home/yannik/pyabc/pyabc/smc.py", line 622, in _generate_valid_proposal
#     m_ss = int(model_prior.rvs())
#   File "/home/yannik/pyabc/pyabc/distance/kernel.py", line 271, in __call__
#     log_2_pi = np.sum(np.log(2) + np.log(np.pi) + np.log(var))
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 183, in rvs
#     return self.distribution.rvs(*args, **kwargs)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 623, in _generate_valid_proposal
#     theta_ss = parameter_priors[m_ss].rvs()
# KeyboardInterrupt
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 423, in rvs
#     return Parameter(**{key: val.rvs() for key, val in self.items()})
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 468, in rvs
#     return self.dist.rvs(*self.args, **kwds)
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 423, in <dictcomp>
#     return Parameter(**{key: val.rvs() for key, val in self.items()})
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 183, in rvs
#     return self.distribution.rvs(*args, **kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 2846, in rvs
#     return super(rv_discrete, self).rvs(*args, **kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 952, in rvs
#     vals = self._rvs(*args)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 468, in rvs
#     return self.dist.rvs(*self.args, **kwds)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 935, in rvs
#     args, loc, scale, size = self._parse_args_rvs(*args, **kwds)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_discrete_distns.py", line 715, in _rvs
#     low = broadcast_to(low, self._size)
#   File "<string>", line 6, in _parse_args_rvs
#   File "<__array_function__ internals>", line 6, in broadcast_to
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 846, in _argcheck_rvs
#     ok = all([bcdim == 1 or bcdim == szdim
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py", line 182, in broadcast_to
#     return _broadcast_to(array, shape, subok=subok, readonly=True)
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py", line 117, in _broadcast_to
#     shape = tuple(shape) if np.iterable(shape) else (shape,)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 283, in iterable
#     iter(y)
# KeyboardInterrupt

# %%
# noisy model

for n_t in arr_n_t:
    mv = ModelVars(n_t=n_t)
    fb = f"cr_{n_t}_noisymodel"
    if os.path.isfile(f"sqlite:///{fb}.db"):
        continue
    abc = pyabc.ABCSMC(
        models=mv.get_model_noisy(),
        parameter_priors=mv.get_prior(),
        distance_function=mv.get_distance(),
        population_size=1000,
    )
    data = {'y': np.load(f"data_{n_t}.npy")}
    abc.new(f"sqlite:///{fb}.db", data)
    abc.run(min_acceptance_rate=1e-3)
    print()
# Out:
# DEBUG:Epsilon:init quantile_epsilon initial_epsilon=from_sample, quantile_multiplier=1
# INFO:History:Start <ABCSMC(id=1, start_time=2019-12-18 15:52:09.253974, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# INFO:Epsilon:initial epsilon is 165.09348249014437
# INFO:ABC:t: 0, eps: 165.09348249014437.
# INFO:ABC:Acceptance rate: 1000 / 2049 = 4.8804e-01, ESS=1.0000e+03.
# DEBUG:Epsilon:new eps, t=1, eps=47.29691411941507
# INFO:ABC:t: 1, eps: 47.29691411941507.
# INFO:ABC:Acceptance rate: 1000 / 1995 = 5.0125e-01, ESS=9.5251e+02.
# DEBUG:Epsilon:new eps, t=2, eps=23.41001532565586
# INFO:ABC:t: 2, eps: 23.41001532565586.
# INFO:ABC:Acceptance rate: 1000 / 2149 = 4.6533e-01, ESS=9.5671e+02.
# DEBUG:Epsilon:new eps, t=3, eps=15.09101557692471
# INFO:ABC:t: 3, eps: 15.09101557692471.
# INFO:ABC:Acceptance rate: 1000 / 2714 = 3.6846e-01, ESS=8.8020e+02.
# DEBUG:Epsilon:new eps, t=4, eps=10.60347211786269
# INFO:ABC:t: 4, eps: 10.60347211786269.
# INFO:ABC:Acceptance rate: 1000 / 4401 = 2.2722e-01, ESS=8.4031e+02.
# DEBUG:Epsilon:new eps, t=5, eps=7.876357257555284
# INFO:ABC:t: 5, eps: 7.876357257555284.
# INFO:ABC:Acceptance rate: 1000 / 7250 = 1.3793e-01, ESS=6.3306e+02.
# DEBUG:Epsilon:new eps, t=6, eps=5.802934103521115
# INFO:ABC:t: 6, eps: 5.802934103521115.
# INFO:ABC:Acceptance rate: 1000 / 14443 = 6.9238e-02, ESS=7.4701e+02.
# DEBUG:Epsilon:new eps, t=7, eps=4.376959908161561
# INFO:ABC:t: 7, eps: 4.376959908161561.
# Process Process-726:
# Process Process-728:
# Process Process-727:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Process-725:
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
# Traceback (most recent call last):
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 642, in _generate_valid_proposal
#     * parameter_priors[m_ss].pdf(theta_ss) > 0):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 446, in pdf
#     res.append(self[key].pdf(val))
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/pyabc/pyabc/random_variables.py", line 189, in pdf
#     return self.distribution.pdf(x, *args, **kwargs)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 639, in _generate_valid_proposal
#     theta_ss = transitions[m_ss].rvs()
#   File "/home/yannik/pyabc/pyabc/model.py", line 227, in accept
#     sum_stats_calculator)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 448, in pdf
#     return self.dist.pdf(x, *self.args, **self.kwds)
#   File "/home/yannik/pyabc/pyabc/smc.py", line 639, in _generate_valid_proposal
#     theta_ss = transitions[m_ss].rvs()
#   File "/home/yannik/pyabc/pyabc/transition/base.py", line 90, in rvs
#     return self.rvs_single()
#   File "/home/yannik/pyabc/pyabc/transition/base.py", line 90, in rvs
#     return self.rvs_single()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-81c56db5aa7c> in <module>
#      12     data = {'y': np.load(f"data_{n_t}.npy")}
#      13     abc.new(f"sqlite:///{fb}.db", data)
# ---> 14     abc.run(min_acceptance_rate=1e-3)
#      15     print()
#
# ~/pyabc/pyabc/smc.py in run(self, minimum_epsilon, max_nr_populations, min_acceptance_rate)
#     882             # perform the sampling
#     883             sample = self.sampler.sample_until_n_accepted(
# --> 884                 self.population_strategy.nr_particles, simulate_one)
#     885
#     886             # retrieve accepted population
#
# ~/pyabc/pyabc/sampler/base.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     143     """
#     144     def sample_until_n_accepted(self, n, simulate_one, all_accepted=False):
# --> 145         sample = f(self, n, simulate_one, all_accepted)
#     146         if sample.n_accepted != n:
#     147             raise AssertionError(
#
# ~/pyabc/pyabc/sampler/multicore_evaluation_parallel.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     115         n_done = 0
#     116         while n_done < len(processes):
# --> 117             val = get_if_worker_healthy(processes, queue)
#     118             if val == DONE:
#     119                 n_done += 1
#
# ~/pyabc/pyabc/sampler/multicorebase.py in get_if_worker_healthy(workers, queue)
#      51     while True:
#      52         try:
# ---> 53             item = queue.get(True, 5)
#      54             return item
#      55         except Empty:
#
# ~/anaconda3/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
#   File "/home/yannik/pyabc/pyabc/transition/transitionmeta.py", line 37, in rvs_single
#     return f(self)
#   File "/home/yannik/pyabc/pyabc/model.py", line 121, in summary_statistics
#     raw_data = self.sample(pars)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py", line 1671, in pdf
#     place(output, cond, self._pdf(*goodargs) / scale)
#   File "/home/yannik/pyabc/pyabc/transition/transitionmeta.py", line 37, in rvs_single
#     return f(self)
#   File "<__array_function__ internals>", line 6, in place
#   File "/home/yannik/pyabc/pyabc/transition/multivariatenormal.py", line 73, in rvs_single
#     sample = self.X.sample(weights=self.w).iloc[0]
#   File "/home/yannik/pyabc/pyabc/transition/multivariatenormal.py", line 73, in rvs_single
#     sample = self.X.sample(weights=self.w).iloc[0]
#   File "/home/yannik/pyabc/pyabc/model.py", line 270, in sample
#     return self.sample_function(pars)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 1684, in place
#     @array_function_dispatch(_place_dispatcher)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1410, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 2134, in _getitem_axis
#     return self._get_loc(key, axis=axis)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 4948, in sample
#     if weights.sum() != 0:
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 57, in model_noisy
#     + self.noise_std * self.noise_model(1, self.n_t)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 160, in _get_loc
#     return self.obj._ixs(key, axis=axis)
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 2920, in _ixs
#     dtype=new_values.dtype,
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 11573, in stat_func
#     if skipna is None:
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py", line 317, in __init__
#     self.name = name
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 5192, in __setattr__
#     object.__getattribute__(self, name)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py", line 458, in name
#     return self._name
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 5172, in __getattr__
#     name in self._internal_names_set
# KeyboardInterrupt

# %% [markdown]
# ## Plots
