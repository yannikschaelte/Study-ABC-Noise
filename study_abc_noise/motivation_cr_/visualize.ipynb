# %%
import pyabc
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from study_abc_noise.model.conversion_reaction import *

mv = ConversionReaction1dModelVars()

# %% [markdown]
# ## Concept

# %%
db_files = ["h_incorrect.db", "h_noisymodel.db", "h_stochasticacceptor.db"]
hs = [pyabc.History(f"sqlite:///{f}") for f in db_files]

labels = ['No noise considered', 'Noisy model', 'Stochastic acceptor']
ids = ["incorrect", "noisymodel", "stochasticacceptor"]
colors = ['C2', 'C1', 'C0']
ts = [3, 8, None]
# find correct values
_, data = pickle.load(open("data.dat", 'rb'))
posterior_scaled = get_posterior_scaled_1d(mv, data)
xs = np.linspace(mv.limits['p0'][0], mv.limits['p0'][1], 200)
true_vals = [posterior_scaled([x]) for x in xs]

color_truth = 'k'

for h, t, id_, c in zip(hs, ts, ids, colors):
    ax = pyabc.visualization.plot_histogram_1d(
        h, 'p0', t=t, xmin=mv.limits['p0'][0], xmax=mv.limits['p0'][1],
        size=(3, 2), bins=40, color=c)
    ax.plot(xs, true_vals, color=color_truth)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel(None)
    plt.axis('off')
    plt.tight_layout()
    for fmt in ['png', 'svg']:
        plt.savefig(f"hist_{id_}.{fmt}", format=f'{fmt}')
# Out:
# Normalization: 18637399012.12633

# %% [markdown]
# ## Motivation

# %% [markdown]
# ### Optimize

# %%
from study_abc_noise.optimize import multistart_on_kernel

# optimize
result = multistart_on_kernel(mv, data)

kernel_l1 = pyabc.distance.IndependentLaplaceKernel(
    mv.noise_std * np.ones(mv.n_t))

result_l1 = multistart_on_kernel(mv, data, kernel_l1)

# l2
optimal_parameter = result.optimize_result.get_for_key('x')[0]
optimal_value = result.optimize_result.get_for_key('fval')[0]
print("optimal parameter l2: ", optimal_parameter)
print("optimal value l2: ", optimal_value)

distance_value = 2 * (optimal_value - 0.5 * (mv.n_t * np.log(2 * np.pi * mv.noise_std**2)))
print("optimal distance l2: ", distance_value)

# l1

optimal_parameter_l1 = result_l1.optimize_result.get_for_key('x')[0]
optimal_value_l1 = result_l1.optimize_result.get_for_key('fval')[0]
print("optimal parameter l1: ", optimal_parameter_l1)
print("optimal value l1: ", optimal_value_l1)

distance_value_l1 = (optimal_value_l1 - (mv.n_t * np.log(2 *  mv.noise_std)))
print("optimal distance l1: ", distance_value_l1)
# Out:
# INFO:pypesto.engine.task:Executing task 0.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0047s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 1.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0038s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 2.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0094s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 3.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0044s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 4.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0287s, n_fval=52.
# INFO:pypesto.engine.task:Executing task 5.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0277s, n_fval=70.
# INFO:pypesto.engine.task:Executing task 6.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0082s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 7.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0091s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 8.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0212s, n_fval=24.
# INFO:pypesto.engine.task:Executing task 9.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0137s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 10.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0486s, n_fval=82.
# INFO:pypesto.engine.task:Executing task 11.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0058s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 12.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0158s, n_fval=28.
# INFO:pypesto.engine.task:Executing task 13.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0045s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 14.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0267s, n_fval=28.
# INFO:pypesto.engine.task:Executing task 15.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0065s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 16.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0175s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 17.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0316s, n_fval=32.
# INFO:pypesto.engine.task:Executing task 18.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0089s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 19.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0123s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 20.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0087s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 21.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0319s, n_fval=26.
# INFO:pypesto.engine.task:Executing task 22.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0234s, n_fval=28.
# INFO:pypesto.engine.task:Executing task 23.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0214s, n_fval=26.
# INFO:pypesto.engine.task:Executing task 24.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0184s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 25.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0061s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 26.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0202s, n_fval=24.
# INFO:pypesto.engine.task:Executing task 27.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0303s, n_fval=34.
# INFO:pypesto.engine.task:Executing task 28.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0075s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 29.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0086s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 30.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0093s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 31.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0123s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 32.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0249s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 33.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0196s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 34.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0121s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 35.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0150s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 36.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0069s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 37.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0112s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 38.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0126s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 39.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0173s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 40.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0085s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 41.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0632s, n_fval=64.
# INFO:pypesto.engine.task:Executing task 42.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0328s, n_fval=38.
# INFO:pypesto.engine.task:Executing task 43.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0238s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 44.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0115s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 45.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0140s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 46.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0108s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 47.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0162s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 48.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0142s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 49.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0061s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 50.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0122s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 51.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0214s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 52.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0086s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 53.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0081s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 54.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0087s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 55.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0036s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 56.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0043s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 57.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0213s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 58.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0443s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 59.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0081s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 60.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0088s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 61.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0171s, n_fval=22.
# INFO:pypesto.engine.task:Executing task 62.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0115s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 63.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0088s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 64.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0064s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 65.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0110s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 66.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0204s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 67.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0231s, n_fval=32.
# INFO:pypesto.engine.task:Executing task 68.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0269s, n_fval=34.
# INFO:pypesto.engine.task:Executing task 69.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0056s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 70.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0116s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 71.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0163s, n_fval=26.
# INFO:pypesto.engine.task:Executing task 72.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0594s, n_fval=90.
# INFO:pypesto.engine.task:Executing task 73.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0166s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 74.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0657s, n_fval=92.
# INFO:pypesto.engine.task:Executing task 75.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0069s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 76.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0098s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 77.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0081s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 78.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0239s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 79.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0095s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 80.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0120s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 81.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0207s, n_fval=28.
# INFO:pypesto.engine.task:Executing task 82.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0078s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 83.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0156s, n_fval=22.
# INFO:pypesto.engine.task:Executing task 84.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0121s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 85.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0180s, n_fval=30.
# INFO:pypesto.engine.task:Executing task 86.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0315s, n_fval=48.
# INFO:pypesto.engine.task:Executing task 87.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0087s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 88.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0086s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 89.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0160s, n_fval=22.
# INFO:pypesto.engine.task:Executing task 90.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0185s, n_fval=28.
# INFO:pypesto.engine.task:Executing task 91.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0074s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 92.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0116s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 93.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0102s, n_fval=10.
# INFO:pypesto.engine.task:Executing task 94.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0415s, n_fval=74.
# INFO:pypesto.engine.task:Executing task 95.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0364s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 96.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0051s, n_fval=14.
# INFO:pypesto.engine.task:Executing task 97.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0112s, n_fval=26.
# INFO:pypesto.engine.task:Executing task 98.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0143s, n_fval=36.
# INFO:pypesto.engine.task:Executing task 99.
# INFO:pypesto.optimize.optimizer:Final fval=-26.4441, time=0.0053s, n_fval=12.
# INFO:pypesto.engine.task:Executing task 0.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0338s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 1.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0330s, n_fval=56.
# INFO:pypesto.engine.task:Executing task 2.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0360s, n_fval=130.
# INFO:pypesto.engine.task:Executing task 3.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0485s, n_fval=128.
# INFO:pypesto.engine.task:Executing task 4.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0336s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 5.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0309s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 6.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0482s, n_fval=130.
# INFO:pypesto.engine.task:Executing task 7.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0474s, n_fval=146.
# INFO:pypesto.engine.task:Executing task 8.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0240s, n_fval=76.
# INFO:pypesto.engine.task:Executing task 9.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0394s, n_fval=124.
# INFO:pypesto.engine.task:Executing task 10.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0404s, n_fval=130.
# INFO:pypesto.engine.task:Executing task 11.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0389s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 12.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0289s, n_fval=82.
# INFO:pypesto.engine.task:Executing task 13.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0501s, n_fval=134.
# INFO:pypesto.engine.task:Executing task 14.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0248s, n_fval=86.
# INFO:pypesto.engine.task:Executing task 15.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0362s, n_fval=90.
# INFO:pypesto.engine.task:Executing task 16.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0391s, n_fval=92.
# INFO:pypesto.engine.task:Executing task 17.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0295s, n_fval=82.
# INFO:pypesto.engine.task:Executing task 18.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0461s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 19.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0516s, n_fval=140.
# INFO:pypesto.engine.task:Executing task 20.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0548s, n_fval=94.
# INFO:pypesto.engine.task:Executing task 21.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0453s, n_fval=120.
# INFO:pypesto.engine.task:Executing task 22.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0511s, n_fval=134.
# INFO:pypesto.engine.task:Executing task 23.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0414s, n_fval=100.
# INFO:pypesto.engine.task:Executing task 24.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0206s, n_fval=60.
# INFO:pypesto.engine.task:Executing task 25.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0421s, n_fval=118.
# INFO:pypesto.engine.task:Executing task 26.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0354s, n_fval=98.
# INFO:pypesto.engine.task:Executing task 27.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0470s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 28.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0393s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 29.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0453s, n_fval=134.
# INFO:pypesto.engine.task:Executing task 30.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0330s, n_fval=96.
# INFO:pypesto.engine.task:Executing task 31.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0465s, n_fval=142.
# INFO:pypesto.engine.task:Executing task 32.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0248s, n_fval=88.
# INFO:pypesto.engine.task:Executing task 33.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0321s, n_fval=92.
# INFO:pypesto.engine.task:Executing task 34.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0318s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 35.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0323s, n_fval=78.
# INFO:pypesto.engine.task:Executing task 36.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0318s, n_fval=78.
# INFO:pypesto.engine.task:Executing task 37.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0436s, n_fval=130.
# INFO:pypesto.engine.task:Executing task 38.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0210s, n_fval=72.
# INFO:pypesto.engine.task:Executing task 39.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0286s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 40.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0384s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 41.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0356s, n_fval=92.
# INFO:pypesto.engine.task:Executing task 42.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0344s, n_fval=86.
# INFO:pypesto.engine.task:Executing task 43.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0428s, n_fval=116.
# INFO:pypesto.engine.task:Executing task 44.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0234s, n_fval=76.
# INFO:pypesto.engine.task:Executing task 45.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0348s, n_fval=94.
# INFO:pypesto.engine.task:Executing task 46.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0436s, n_fval=132.
# INFO:pypesto.engine.task:Executing task 47.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0267s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 48.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0459s, n_fval=130.
# INFO:pypesto.engine.task:Executing task 49.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0314s, n_fval=88.
# INFO:pypesto.engine.task:Executing task 50.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0235s, n_fval=64.
# INFO:pypesto.engine.task:Executing task 51.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0471s, n_fval=140.
# INFO:pypesto.engine.task:Executing task 52.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0144s, n_fval=40.
# INFO:pypesto.engine.task:Executing task 53.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0461s, n_fval=124.
# INFO:pypesto.engine.task:Executing task 54.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0367s, n_fval=120.
# INFO:pypesto.engine.task:Executing task 55.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0481s, n_fval=140.
# INFO:pypesto.engine.task:Executing task 56.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0283s, n_fval=86.
# INFO:pypesto.engine.task:Executing task 57.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0272s, n_fval=82.
# INFO:pypesto.engine.task:Executing task 58.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0426s, n_fval=128.
# INFO:pypesto.engine.task:Executing task 59.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0264s, n_fval=82.
# INFO:pypesto.engine.task:Executing task 60.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0260s, n_fval=72.
# INFO:pypesto.engine.task:Executing task 61.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0432s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 62.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0317s, n_fval=92.
# INFO:pypesto.engine.task:Executing task 63.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0596s, n_fval=112.
# INFO:pypesto.engine.task:Executing task 64.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0438s, n_fval=94.
# INFO:pypesto.engine.task:Executing task 65.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0275s, n_fval=72.
# INFO:pypesto.engine.task:Executing task 66.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0316s, n_fval=90.
# INFO:pypesto.engine.task:Executing task 67.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0286s, n_fval=62.
# INFO:pypesto.engine.task:Executing task 68.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0379s, n_fval=78.
# INFO:pypesto.engine.task:Executing task 69.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0330s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 70.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0455s, n_fval=124.
# INFO:pypesto.engine.task:Executing task 71.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0412s, n_fval=142.
# INFO:pypesto.engine.task:Executing task 72.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0380s, n_fval=116.
# INFO:pypesto.engine.task:Executing task 73.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0368s, n_fval=98.
# INFO:pypesto.engine.task:Executing task 74.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0362s, n_fval=88.
# INFO:pypesto.engine.task:Executing task 75.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0344s, n_fval=72.
# INFO:pypesto.engine.task:Executing task 76.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0309s, n_fval=52.
# INFO:pypesto.engine.task:Executing task 77.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0446s, n_fval=86.
# INFO:pypesto.engine.task:Executing task 78.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0388s, n_fval=120.
# INFO:pypesto.engine.task:Executing task 79.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0297s, n_fval=88.
# INFO:pypesto.engine.task:Executing task 80.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0364s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 81.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0412s, n_fval=118.
# INFO:pypesto.engine.task:Executing task 82.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0175s, n_fval=66.
# INFO:pypesto.engine.task:Executing task 83.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0373s, n_fval=104.
# INFO:pypesto.engine.task:Executing task 84.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0413s, n_fval=128.
# INFO:pypesto.engine.task:Executing task 85.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0224s, n_fval=84.
# INFO:pypesto.engine.task:Executing task 86.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0387s, n_fval=96.
# INFO:pypesto.engine.task:Executing task 87.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0537s, n_fval=140.
# INFO:pypesto.engine.task:Executing task 88.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0714s, n_fval=138.
# INFO:pypesto.engine.task:Executing task 89.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0801s, n_fval=132.
# INFO:pypesto.engine.task:Executing task 90.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0613s, n_fval=80.
# INFO:pypesto.engine.task:Executing task 91.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0757s, n_fval=102.
# INFO:pypesto.engine.task:Executing task 92.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0299s, n_fval=72.
# INFO:pypesto.engine.task:Executing task 93.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0464s, n_fval=146.
# INFO:pypesto.engine.task:Executing task 94.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0429s, n_fval=126.
# INFO:pypesto.engine.task:Executing task 95.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0366s, n_fval=114.
# INFO:pypesto.engine.task:Executing task 96.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0482s, n_fval=132.
# INFO:pypesto.engine.task:Executing task 97.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0351s, n_fval=90.
# INFO:pypesto.engine.task:Executing task 98.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0213s, n_fval=58.
# INFO:pypesto.engine.task:Executing task 99.
# INFO:pypesto.optimize.optimizer:Final fval=-25.6040, time=0.0446s, n_fval=130.
# optimal parameter l2:  [0.05801482]
# optimal value l2:  -26.44410636447256
# optimal distance l2:  6.973476715524342
# optimal parameter l1:  [0.05882004]
# optimal value l1:  -25.604012563384988
# optimal distance l1:  6.584745685297019

# %% [markdown]
# ### Plot

# %%
db_files = ["h_incorrect.db", "h_incorrect_l1.db", "h_noisymodel.db"]
hs = [pyabc.History(f"sqlite:///{f}") for f in db_files]

labels = ['Ignore noise, l2 distance', 
          'Ignore noise, l1 distance',
          'Noisy model']

ax_data = plt.subplot2grid((2, 3), (0, 0))
ax_epsilons = plt.subplot2grid((2, 3), (0, 1), colspan=2)
axes_h = [plt.subplot2grid((2, 3), (1, i)) for i in [0, 1, 2]]
color_truth = 'grey'
colors_h = ['C1', 'C2', 'C3']

# plot epsilons
ax_epsilons.axhline(np.log10(distance_value), linestyle='dotted', color='C1')
ax_epsilons.axhline(np.log10(distance_value_l1), linestyle='dotted', color='C2')
ax_epsilons.spines['right'].set_visible(False)
ax_epsilons.spines['top'].set_visible(False)
pyabc.visualization.plot_epsilons(hs, labels, scale='log10', size=(9, 6), colors=colors_h, ax=ax_epsilons)
ax_epsilons.set_title(None)

# data
data_nonoise, data = pickle.load(open("data.dat", 'rb'))

ax_data.plot(mv.get_ts(), data_nonoise['y'], '-', color='black', label='model simulation')
ax_data.plot(mv.get_ts(), data['y'], '*', color='black', label='noisy data')
ax_data.legend()
ax_data.set_xlabel("Time")
ax_data.set_ylabel("Data")
#ax_data.set_title("Model values")
ax_data.spines['right'].set_visible(False)
ax_data.spines['top'].set_visible(False)

# find correct values
posterior_scaled = get_posterior_scaled_1d(mv, data)
xs = np.linspace(mv.limits['p0'][0], mv.limits['p0'][1], 200)
true_vals = [posterior_scaled([x]) for x in xs]

# plot histories
for i, (h, label, color) in enumerate(zip(hs, labels, colors_h)):
    pyabc.visualization.plot_histogram_1d(
        h, 'p0', xmin=mv.limits['p0'][0], xmax=mv.limits['p0'][1],
        size=(3, 2), bins=40, ax=axes_h[i], color=color, refval={'p0': 0.06}, refval_color='grey')
    axes_h[i].plot(xs, true_vals, color=color_truth, linestyle='--', label="True posterior")
    axes_h[i].set_title(label)
    axes_h[i].set_xlabel("")
    axes_h[i].spines['right'].set_visible(False)
    axes_h[i].spines['top'].set_visible(False)

axes_h[1].set_xlabel("Parameter $\\theta_1$")
axes_h[0].set_ylabel("Density")

# create legend for hists
#lines = [Line2D([0], [0], color=color_truth, linestyle='--'), Line2D([0], [0], color='grey', linestyle='dotted')]
#axes_h[0].legend(lines, ["True posterior", "True parameter"])

# add identifiers
plt.figtext(0.0, 0.96, "A", size=16, weight='bold')
plt.figtext(0.35, 0.96, "B", size=16, weight='bold')
plt.figtext(0.0, 0.48, "C", size=16, weight='bold')

# finalize layout
plt.gcf().set_size_inches((8, 5))
plt.gcf().tight_layout()

# save
plt.savefig("motivation_data.png", format='png')
plt.savefig("motivation_data.eps", format='eps')
plt.savefig("motivation_data.svg", format='svg')
# Out:
# Normalization: 18637399012.12633
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
h = pyabc.History("sqlite:///h_stochasticacceptor.db")
_, ax = plt.subplots()
for t in reversed(range(0, h.max_t)):
    pyabc.visualization.plot_kde_1d_highlevel(
        h, t=t, x='p0', xmin=mv.limits['p0'][0], xmax=mv.limits['p0'][1],
        refval = mv.p_true, ax=ax, color='C0', alpha=1/(h.max_t-t+1), label=f"Iteration {t}")
ax.legend()
