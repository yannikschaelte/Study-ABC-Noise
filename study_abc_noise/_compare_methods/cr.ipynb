# %% [markdown]
# This has been used for posters, but not for the main study.

# %%
import pyabc
from study_abc_noise.model import \
    ConversionReactionModelVars as ModelVars
import numpy as np
import scipy.stats as stats
import scipy.integrate as integrate
import matplotlib.pyplot as plt
import logging
import pickle
import os
# %matplotlib inline

# for debugging
df_logger = logging.getLogger('Distance')
df_logger.setLevel(logging.DEBUG)
df_logger = logging.getLogger('Acceptor')
df_logger.setLevel(logging.DEBUG)
df_logger = logging.getLogger('Epsilon')
df_logger.setLevel(logging.DEBUG)

# model
mv = ModelVars(n_t=10)

# data
def get_data():
    try:
        data = pickle.load(open("data_cr.dat", 'rb'))
    except:
        data = mv.get_model_noisy()(mv.p_true)
        pickle.dump(data, open("data_cr.dat", 'wb'))
    return data
data = get_data()
# plot it
mv.viz_data_and_sim(data)

# %%
acceptor = pyabc.StochasticAcceptor()
temperature = pyabc.Temperature()

# define the analysis
abc = pyabc.ABCSMC(
    models=mv.get_model(),
    parameter_priors=mv.get_prior(),
    distance_function=mv.get_kernel(),
    eps=temperature,
    acceptor=acceptor)
h = abc.new("sqlite:///h_cr.db", data)
h = abc.run()
# Out:
# INFO:History:Start <ABCSMC(id=2, start_time=2019-11-21 23:40:21.030030, end_time=None)>
# INFO:ABC:Calibration sample before t=0.
# DEBUG:Acceptor:pdf_norm=5.0130e+01 for t=0.
# INFO:ABC:t: 0, eps: 1478.105588328931.
# DEBUG:Acceptor:Encountered pd=6.2768e+01 > c=5.0130e+01, thus weight=1.0086e+00.
# DEBUG:Acceptor:Encountered pd=8.0782e+01 > c=5.0130e+01, thus weight=1.0210e+00.
# INFO:ABC:Acceptance rate: 100 / 265 = 3.7736e-01, ESS=9.9999e+01.
# DEBUG:Acceptor:pdf_norm=8.0782e+01 for t=1.
# DEBUG:Epsilon:Proposed temperatures: [353.3394403640937, 739.0527941644655].
# INFO:ABC:t: 1, eps: 353.3394403640937.
# DEBUG:Acceptor:Encountered pd=1.2236e+02 > c=8.0782e+01, thus weight=1.1249e+00.
# DEBUG:Acceptor:Encountered pd=9.1273e+01 > c=8.0782e+01, thus weight=1.0301e+00.
# DEBUG:Acceptor:Encountered pd=8.5329e+01 > c=8.0782e+01, thus weight=1.0129e+00.
# INFO:ABC:Acceptance rate: 100 / 326 = 3.0675e-01, ESS=8.8838e+01.
# DEBUG:Acceptor:pdf_norm=1.2236e+02 for t=2.
# DEBUG:Epsilon:Proposed temperatures: [228.40580764578445, 176.66972018204686].
# INFO:ABC:t: 2, eps: 176.66972018204686.
# DEBUG:Acceptor:Encountered pd=1.2478e+02 > c=1.2236e+02, thus weight=1.0138e+00.
# INFO:ABC:Acceptance rate: 100 / 387 = 2.5840e-01, ESS=6.8837e+01.
# DEBUG:Acceptor:pdf_norm=1.2478e+02 for t=3.
# DEBUG:Epsilon:Proposed temperatures: [162.2934532143369, 88.33486009102343].
# INFO:ABC:t: 3, eps: 88.33486009102343.
# DEBUG:Acceptor:Encountered pd=1.2714e+02 > c=1.2478e+02, thus weight=1.0271e+00.
# DEBUG:Acceptor:Encountered pd=1.2615e+02 > c=1.2478e+02, thus weight=1.0157e+00.
# DEBUG:Acceptor:Encountered pd=1.2605e+02 > c=1.2478e+02, thus weight=1.0144e+00.
# INFO:ABC:Acceptance rate: 100 / 635 = 1.5748e-01, ESS=8.0355e+01.
# DEBUG:Acceptor:pdf_norm=1.2714e+02 for t=4.
# DEBUG:Epsilon:Proposed temperatures: [76.6873014333307, 44.167430045511715].
# INFO:ABC:t: 4, eps: 44.167430045511715.
# DEBUG:Acceptor:Encountered pd=1.2719e+02 > c=1.2714e+02, thus weight=1.0011e+00.
# DEBUG:Acceptor:Encountered pd=1.2733e+02 > c=1.2714e+02, thus weight=1.0043e+00.
# DEBUG:Acceptor:Encountered pd=1.2754e+02 > c=1.2714e+02, thus weight=1.0091e+00.
# INFO:ABC:Acceptance rate: 100 / 542 = 1.8450e-01, ESS=6.0955e+01.
# DEBUG:Acceptor:pdf_norm=1.2754e+02 for t=5.
# DEBUG:Epsilon:Proposed temperatures: [37.64929334444085, 22.083715022755857].
# INFO:ABC:t: 5, eps: 22.083715022755857.
# DEBUG:Acceptor:Encountered pd=1.2763e+02 > c=1.2754e+02, thus weight=1.0040e+00.
# DEBUG:Acceptor:Encountered pd=1.2762e+02 > c=1.2754e+02, thus weight=1.0037e+00.
# DEBUG:Acceptor:Encountered pd=1.2758e+02 > c=1.2754e+02, thus weight=1.0019e+00.
# INFO:ABC:Acceptance rate: 100 / 541 = 1.8484e-01, ESS=8.8458e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=6.
# DEBUG:Epsilon:Proposed temperatures: [14.423928900843308, 11.041857511377929].
# INFO:ABC:t: 6, eps: 11.041857511377929.
# INFO:ABC:Acceptance rate: 100 / 387 = 2.5840e-01, ESS=9.0741e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=7.
# DEBUG:Epsilon:Proposed temperatures: [5.585147054382892, 5.520928755688964].
# INFO:ABC:t: 7, eps: 5.520928755688964.
# INFO:ABC:Acceptance rate: 100 / 344 = 2.9070e-01, ESS=8.7950e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=8.
# DEBUG:Epsilon:Proposed temperatures: [2.9702708588464684, 2.760464377844482].
# INFO:ABC:t: 8, eps: 2.760464377844482.
# DEBUG:Acceptor:Encountered pd=1.2763e+02 > c=1.2763e+02, thus weight=1.0004e+00.
# DEBUG:Acceptor:Encountered pd=1.2763e+02 > c=1.2763e+02, thus weight=1.0025e+00.
# INFO:ABC:Acceptance rate: 100 / 369 = 2.7100e-01, ESS=8.6958e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=9.
# DEBUG:Epsilon:Proposed temperatures: [1.184632106604566, 1.380232188922241].
# INFO:ABC:t: 9, eps: 1.184632106604566.
# INFO:ABC:Acceptance rate: 100 / 398 = 2.5126e-01, ESS=7.9746e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=10.
# DEBUG:Epsilon:Proposed temperatures: [1.0, 0.592316053302283].
# INFO:ABC:t: 10, eps: 1.0.
# INFO:ABC:Acceptance rate: 100 / 258 = 3.8760e-01, ESS=7.8072e+01.
# DEBUG:Acceptor:pdf_norm=1.2763e+02 for t=11.
# DEBUG:Epsilon:Proposed temperatures: [1.0, 0.5].
# INFO:History:Done <ABCSMC(id=2, start_time=2019-11-21 23:40:21.030030, end_time=2019-11-21 23:40:39.790340)>

# %%
acceptor = pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel)
temperature = pyabc.Temperature()

# define the analysis
abc = pyabc.ABCSMC(
    models=mv.get_model(),
    parameter_priors=mv.get_prior(),
    distance_function=mv.get_kernel(),
    eps=temperature,
    acceptor=acceptor)
h_badc = abc.new("sqlite:///h_cr_badc.db", data)
h_badc = abc.run()
# Out:
# INFO:History:Start <ABCSMC(id=2, start_time=2019-11-21 23:40:43.505384, end_time=None)>
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=0.
# INFO:ABC:Calibration sample before t=0.
# INFO:ABC:t: 0, eps: 1592.6621574944986.
# INFO:ABC:Acceptance rate: 100 / 303 = 3.3003e-01, ESS=1.0000e+02.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=1.
# DEBUG:Epsilon:Proposed temperatures: [686.5019222213743, 796.3310787472493].
# INFO:ABC:t: 1, eps: 686.5019222213743.
# INFO:ABC:Acceptance rate: 100 / 282 = 3.5461e-01, ESS=9.2406e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=2.
# DEBUG:Epsilon:Proposed temperatures: [354.6468173113365, 343.2509611106872].
# INFO:ABC:t: 2, eps: 343.2509611106872.
# INFO:ABC:Acceptance rate: 100 / 355 = 2.8169e-01, ESS=8.8764e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=3.
# DEBUG:Epsilon:Proposed temperatures: [253.6201848835062, 171.6254805553436].
# INFO:ABC:t: 3, eps: 171.6254805553436.
# INFO:ABC:Acceptance rate: 100 / 422 = 2.3697e-01, ESS=8.8889e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=4.
# DEBUG:Epsilon:Proposed temperatures: [168.52907546119036, 85.8127402776718].
# INFO:ABC:t: 4, eps: 85.8127402776718.
# INFO:ABC:Acceptance rate: 100 / 675 = 1.4815e-01, ESS=7.6321e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=5.
# DEBUG:Epsilon:Proposed temperatures: [115.49060126833524, 42.9063701388359].
# INFO:ABC:t: 5, eps: 42.9063701388359.
# INFO:ABC:Acceptance rate: 100 / 1094 = 9.1408e-02, ESS=6.5194e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=6.
# DEBUG:Epsilon:Proposed temperatures: [54.5540951821647, 21.45318506941795].
# INFO:ABC:t: 6, eps: 21.45318506941795.
# INFO:ABC:Acceptance rate: 100 / 1405 = 7.1174e-02, ESS=8.6739e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=7.
# DEBUG:Epsilon:Proposed temperatures: [36.74883090370982, 10.726592534708974].
# INFO:ABC:t: 7, eps: 10.726592534708974.
# INFO:ABC:Acceptance rate: 100 / 3000 = 3.3333e-02, ESS=8.8684e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=8.
# DEBUG:Epsilon:Proposed temperatures: [25.094650393320588, 5.363296267354487].
# INFO:ABC:t: 8, eps: 5.363296267354487.
# INFO:ABC:Acceptance rate: 100 / 16707 = 5.9855e-03, ESS=7.3300e+01.
# DEBUG:Acceptor:pdf_norm=1.4965e+02 for t=9.
# DEBUG:Epsilon:Proposed temperatures: [23.12322746034725, 2.6816481336772435].
# INFO:ABC:t: 9, eps: 2.6816481336772435.
# Process Process-224:
# Process Process-221:
# Traceback (most recent call last):
# Process Process-223:
# Process Process-222:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 639, in _generate_valid_proposal
#     theta_ss = transitions[m_ss].rvs()
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 26, in work
#     with n_eval.get_lock():
#   File "/home/yannik/pyabc/pyabc/sampler/multicore_evaluation_parallel.py", line 30, in work
#     new_sim = simulate_one()
#   File "/home/yannik/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 584, in simulate_one
#     transitions)
# KeyboardInterrupt
#   File "/home/yannik/pyabc/pyabc/smc.py", line 595, in simulate_one
#     weight_function)
#   File "/home/yannik/pyabc/pyabc/transition/base.py", line 90, in rvs
#     return self.rvs_single()
#   File "/home/yannik/pyabc/pyabc/smc.py", line 680, in _evaluate_proposal
#     x_0)
#   File "/home/yannik/pyabc/pyabc/transition/transitionmeta.py", line 37, in rvs_single
#     return f(self)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1ebeb6d13a82> in <module>
#      10     acceptor=acceptor)
#      11 h_badc = abc.new("sqlite:///h_gaussian_badc.db", data)
# ---> 12 h_badc = abc.run()
#
# ~/pyabc/pyabc/smc.py in run(self, minimum_epsilon, max_nr_populations, min_acceptance_rate)
#     882             # perform the sampling
#     883             sample = self.sampler.sample_until_n_accepted(
# --> 884                 self.population_strategy.nr_particles, simulate_one)
#     885
#     886             # retrieve accepted population
#
# ~/pyabc/pyabc/sampler/base.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     143     """
#     144     def sample_until_n_accepted(self, n, simulate_one, all_accepted=False):
# --> 145         sample = f(self, n, simulate_one, all_accepted)
#     146         if sample.n_accepted != n:
#     147             raise AssertionError(
#
# ~/pyabc/pyabc/sampler/multicore_evaluation_parallel.py in sample_until_n_accepted(self, n, simulate_one, all_accepted)
#     115         n_done = 0
#     116         while n_done < len(processes):
# --> 117             val = get_if_worker_healthy(processes, queue)
#     118             if val == DONE:
#     119                 n_done += 1
#
# ~/pyabc/pyabc/sampler/multicorebase.py in get_if_worker_healthy(workers, queue)
#      51     while True:
#      52         try:
# ---> 53             item = queue.get(True, 5)
#      54             return item
#      55         except Empty:
#
# ~/anaconda3/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     111                 self._rlock.release()
#     112         # unserialize the data after having released the lock
# --> 113         return _ForkingPickler.loads(res)
#     114
#     115     def qsize(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _new_Index(cls, d)
#     181
#     182         return _new_PeriodIndex(cls, **d)
# --> 183     return cls.__new__(cls, **d)
#     184
#     185
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     368
#     369         # extension dtype
# --> 370         elif is_extension_array_dtype(data) or is_extension_array_dtype(dtype):
#     371             data = np.asarray(data)
#     372             if not (dtype is None or is_object_dtype(dtype)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1787     """
#    1788     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
# -> 1789     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1790
#    1791
#
# KeyboardInterrupt:
#   File "/home/yannik/pyabc/pyabc/transition/multivariatenormal.py", line 73, in rvs_single
#     sample = self.X.sample(weights=self.w).iloc[0]
#   File "/home/yannik/pyabc/pyabc/smc.py", line 639, in _generate_valid_proposal
#     theta_ss = transitions[m_ss].rvs()
#   File "/home/yannik/pyabc/pyabc/transition/base.py", line 90, in rvs
#     return self.rvs_single()
#   File "/home/yannik/pyabc/pyabc/model.py", line 227, in accept
#     sum_stats_calculator)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 4930, in sample
#     weights = pd.Series(weights, dtype="float64")
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py", line 311, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/home/yannik/pyabc/pyabc/transition/transitionmeta.py", line 37, in rvs_single
#     return f(self)
#   File "/home/yannik/pyabc/pyabc/model.py", line 121, in summary_statistics
#     raw_data = self.sample(pars)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 664, in sanitize_array
#     subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#   File "/home/yannik/pyabc/pyabc/model.py", line 270, in sample
#     return self.sample_function(pars)
#   File "/home/yannik/pyabc/pyabc/transition/multivariatenormal.py", line 73, in rvs_single
#     sample = self.X.sample(weights=self.w).iloc[0]
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 50, in model
#     y = x(p, self.x0, self.get_ts())[1, :]
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 775, in _try_cast
#     if maybe_castable(arr) and not copy and dtype is None:
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 4948, in sample
#     if weights.sum() != 0:
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 11587, in stat_func
#     min_count=min_count,
#   File "/home/yannik/Documents/Project8_pyABC_Noise/Study-ABC-Noise/study_abc_noise/model/conversion_reaction.py", line 160, in x
#     [- p0 + p0 * e, - p0 - p1 * e]])
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 871, in maybe_castable
#     kind = arr.dtype.kind
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py", line 4082, in _reduce
#     with np.errstate(all="ignore"):
# KeyboardInterrupt
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 442, in __enter__
#     self.oldstate = seterr(**self.kwargs)
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 118, in seterr
#     old = geterr()
#   File "/home/yannik/anaconda3/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 179, in geterr
#     val = (maskvalue >> SHIFT_DIVIDEBYZERO) & mask
# KeyboardInterrupt

# %%
acceptor = pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel)
temperature = pyabc.Temperature()

# define the analysis
abc = pyabc.ABCSMC(
    models=mv.get_model(),
    parameter_priors=mv.get_prior(),
    distance_function=mv.get_kernel(),
    eps=temperature,
    acceptor=acceptor)
h_badc = abc.new("sqlite:///h_cr_badc.db", data)
h_badc = abc.run(max_nr_populations=1)

# %%
acceptor = pyabc.StochasticAcceptor(pdf_norm_method=pyabc.pdf_norm_from_kernel)
temperature = pyabc.Temperature(initial_temperature=1000)

# define the analysis
abc = pyabc.ABCSMC(
    models=mv.get_model(),
    parameter_priors=mv.get_prior(),
    distance_function=mv.get_kernel(),
    eps=temperature,
    acceptor=acceptor)
h_badc = abc.new("sqlite:///h_cr_badc_badinittemp.db", data)
h_badc = abc.run()

# %%
import pyabc
import matplotlib.pyplot as plt
# %matplotlib inline

h = pyabc.History("sqlite:///h_cr.db")
h_noisy_model = pyabc.History("sqlite:///h_cr_noisy_model.db")
h_badc = pyabc.History("sqlite:///h_cr_badc.db")
h_rejection = pyabc.History("sqlite:///h_cr_rejection_badc.db")

histories = [h_noisy_model, h_rejection, h_badc, h]
labels = ["Noisy model", "Rejection ABC", "ABC-SMC", "ABC-SMC Adaptive c"]
pyabc.visualization.plot_total_sample_numbers(histories, labels, yscale='log10', rotation=10)
plt.gcf().set_size_inches((5,3.5))
plt.tight_layout()
plt.savefig("total_samples.svg", format='svg')

pyabc.visualization.plot_sample_numbers([h_badc, h], ["ABC-SMC", "ABC-SMC Adaptive c"])
plt.gcf().set_size_inches((6,4))
plt.tight_layout()
plt.savefig("total_samples_adaptive_c.svg", format='svg')

# %%
fig, arr_ax = plt.subplots(1,2)
for t in range(h_noisy_model.max_t+1):
    for i, p in enumerate(['p0', 'p1']):
        pyabc.visualization.plot_kde_1d_highlevel(h_noisy_model, x='p0', t=t, xmin=mv.limits[p][0], xmax=mv.limits[p][1], ax=arr_ax[i])
for i, p in enumerate(['p0', 'p1']):
    pyabc.visualization.plot_kde_1d_highlevel(h, x='p0', xmin=mv.limits[p][0], xmax=mv.limits[p][1], ax=arr_ax[i], color='k')
                
fig.set_size_inches((21,6))

# %%
import scipy as sp
import numpy as np

model = mv.get_model()
prior = mv.get_prior()

def normal_dty_1d(y_bar, y, sigma):
    dty = ( 1 / np.sqrt( 2 * np.pi * sigma**2 ) 
            * np.exp( - ( (y_bar - y) / sigma)**2 / 2) )
    return dty

def normal_dty(y_bar, y, sigma):
    """
    y_bar: size dim
        point at which to evaluate the density
    y, sigma: size dim
        For N(y, sigma).
    """
    dim = len(y_bar)
    dties = np.zeros(dim)
    for j in range(dim):
        dties[j] = normal_dty_1d(y_bar[j], y[j], sigma[j])
    dty = np.prod(dties)
    return dty

def integrand_from_prior(th, c):
    if type(th) is list:
        th = {'p0': th[0], 'p1': th[1]}

    # data
    y = model(th)['y'].flatten()
    y_obs = data['y'].flatten()

    sigma = mv.noise_std * np.ones(len(y))

    # likelihood
    likelihood_val = normal_dty(y_obs, y, sigma)

    # prior
    prior_val = prior.pdf(th)

    return (likelihood_val / c) * prior_val


c_max = normal_dty(data['y'].flatten(), data['y'].flatten(), mv.noise_std * np.ones(mv.n_t))
print(c_max, np.log(c_max))

def integrand_from_prior_c_max(th):
    return integrand_from_prior(th, c_max)

def true_posterior_unscaled(th):
    if type(th) is list:
        th = {'p0': th[0], 'p1': th[1]}

    # data
    y = model(th)['y'].flatten()
    y_obs = data['y'].flatten()
    
    sigma = mv.noise_std * np.ones(len(y))

    # likelihood
    likelihood_val = normal_dty(y_obs, y, sigma)

    # prior
    prior_val = prior.pdf(th)

    # posterior value
    unscaled_posterior = likelihood_val * prior_val

    return unscaled_posterior

c_found = np.exp(2.7233e1)

true_posterior_normalization = integrate.dblquad(lambda x, y: true_posterior_unscaled([x,y]), 
                                                 mv.limits['p0'][0], mv.limits['p0'][1], 
                                                 lambda x: mv.limits['p1'][0], 
                                                 lambda x: mv.limits['p1'][1])[0]

def true_posterior(th):
    return true_posterior_unscaled(th) / true_posterior_normalization

def integrand_from_posterior(th, c):
    if type(th) is list:
        th = {'p0': th[0], 'p1': th[1]}

    # data 
    y = model(th)['y'].flatten()
    y_obs = data['y'].flatten()
    
    sigma = mv.noise_std * np.ones(len(y))

    # likelihood
    likelihood_val = normal_dty(y_obs, y, sigma)

    # posterior
    posterior_val = true_posterior(th)

    return (likelihood_val / c)  * posterior_val

def integrand_from_posterior_c_max(th):
    return integrand_from_posterior(th, c_max)
def integrand_from_posterior_c_found(th):
    return integrand_from_posterior(th, c_found)


integral_prior_max = sp.integrate.dblquad(lambda x, y: integrand_from_prior_c_max([x,y]),
                                          mv.limits['p0'][0], mv.limits['p0'][1],
                                          lambda x: mv.limits['p1'][0],
                                          lambda x: mv.limits['p1'][1])[0]
integral_posterior_found = sp.integrate.dblquad(lambda x, y: integrand_from_posterior_c_max([x,y]),
                                                mv.limits['p0'][0], mv.limits['p0'][1],
                                                lambda x: mv.limits['p1'][0], 
                                                lambda x: mv.limits['p1'][1])[0]
integral_posterior_found = sp.integrate.dblquad(lambda x, y: integrand_from_posterior_c_found([x,y]),
                                                mv.limits['p0'][0], mv.limits['p0'][1],
                                                lambda x: mv.limits['p1'][0], 
                                                lambda x: mv.limits['p1'][1])[0]
# Out:
# 9972423227091.63 29.930844722234735
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-a37f7303bbb1> in <module>
#     115                                                 mv.limits['p0'][0], mv.limits['p0'][1],
#     116                                                 lambda x: mv.limits['p1'][0],
# --> 117                                                 lambda x: mv.limits['p1'][1])[0]
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     579
#     580     return nquad(func, [temp_ranges, [a, b]], args=args,
# --> 581             opts={"epsabs": epsabs, "epsrel": epsrel})
#     582
#     583
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
#     803     else:
#     804         opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 805     return _NQuad(func, ranges, opts, full_output).integrate(*args)
#     806
#     807
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     858             f = partial(self.integrate, depth=depth+1)
#     859         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 860                       **opt)
#     861         value = quad_r[0]
#     862         abserr = quad_r[1]
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     858             f = partial(self.integrate, depth=depth+1)
#     859         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 860                       **opt)
#     861         value = quad_r[0]
#     862         abserr = quad_r[1]
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-44-a37f7303bbb1> in <lambda>(x, y)
#     112                                                 lambda x: mv.limits['p1'][0],
#     113                                                 lambda x: mv.limits['p1'][1])[0]
# --> 114 integral_posterior_found = sp.integrate.dblquad(lambda x, y: integrand_from_posterior_c_found([x,y]),
#     115                                                 mv.limits['p0'][0], mv.limits['p0'][1],
#     116                                                 lambda x: mv.limits['p1'][0],
#
# <ipython-input-44-a37f7303bbb1> in integrand_from_posterior_c_found(th)
#     101     return integrand_from_posterior(th, c_max)
#     102 def integrand_from_posterior_c_found(th):
# --> 103     return integrand_from_posterior(th, c_found)
#     104
#     105
#
# <ipython-input-44-a37f7303bbb1> in integrand_from_posterior(th, c)
#      94
#      95     # posterior
# ---> 96     posterior_val = true_posterior(th)
#      97
#      98     return (likelihood_val / c)  * posterior_val
#
# <ipython-input-44-a37f7303bbb1> in true_posterior(th)
#      78
#      79 def true_posterior(th):
# ---> 80     return true_posterior_unscaled(th) / true_posterior_normalization
#      81
#      82 def integrand_from_posterior(th, c):
#
# <ipython-input-44-a37f7303bbb1> in true_posterior_unscaled(th)
#      63
#      64     # prior
# ---> 65     prior_val = prior.pdf(th)
#      66
#      67     # posterior value
#
# ~/pyabc/pyabc/random_variables.py in pdf(self, x)
#     444                 try:
#     445                     # works for continuous variables
# --> 446                     res.append(self[key].pdf(val))
#     447                 except AttributeError:
#     448                     # discrete variables do not have a pdf but a pmf
#
# ~/pyabc/pyabc/random_variables.py in pdf(self, x, *args, **kwargs)
#     187
#     188     def pdf(self, x, *args, **kwargs):
# --> 189         return self.distribution.pdf(x, *args, **kwargs)
#     190
#     191     def cdf(self, x, *args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x)
#     446
#     447     def pdf(self, x):   # raises AttributeError in frozen discrete distribution
# --> 448         return self.dist.pdf(x, *self.args, **self.kwds)
#     449
#     450     def logpdf(self, x):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1666         output = zeros(shape(cond), dtyp)
#    1667         putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
# -> 1668         if np.any(cond):
#    1669             goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#    1670             scale, goodargs = goodargs[-1], goodargs[:-1]
#
# KeyboardInterrupt:

# %%
1 / integral_prior_max * 100
# Out:
# 2271624.472431556
